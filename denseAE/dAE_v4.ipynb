# %% [markdown]
# latent space reduced (smaller than N part)

# %%
AEversion = '4'

# %%
import numpy as np
import os, sys, pickle
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import gpustat
try:
    gpustat.print_gpustat()
except:
    pass
# Out:
# imperium-sm.hep.caltech.edu  Sun Jul  7 22:22:12 2019
# [0] GeForce GTX 1080 | 46'C,  54 % |   720 /  8119 MB | ocerri(709M)
# [1] GeForce GTX 1080 | 22'C,   0 % |    11 /  8119 MB |
# [2] GeForce GTX 1080 | 26'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 21'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 25'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [6] GeForce GTX 1080 | 24'C,   0 % |    11 /  8119 MB |
# [7] GeForce GTX 1080 | 25'C,   0 % |    11 /  8119 MB |

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
sys.path.append('../lib')
from progressBar import ProgressBar
from utils import EarlyStopping, createROC_curve

# %%
dnd = []

# %% [markdown]
# ## Get the dataset

# %%
from dataLoaders import ParticleDataset

# %%
dataset = ParticleDataset(template='../data/20190702_50part_PtOrder_v1/{}.npy', N_part=20, N_features=5)

# %%
dataset.loadTrainSM(N_train_max=2e6)
dataset.charge(dataset.SMMix_train)
# Out:
# Fetching Wlnu
# Fetching qcd
# Fetching Zll
# Fetching ttbar
# QCD is limiting, using it for both val and split
# Expected 1.69M train
# Expected 1.69M val
#
# Loading Wlnu
# Reloading QCD for validation
# Loading Zll
# Loading ttbar
# +--------+----------+-------+-------+
# | Sample | Evts tot | Train |  Val  |
# +--------+----------+-------+-------+
# |  Wlnu  |  2000k   | 1000k | 1000k |
# |  qcd   |   690k   |  571k |  571k |
# |  Zll   |  1000k   |  113k |  113k |
# | ttbar  |  1000k   |   5k  |   5k  |
# +--------+----------+-------+-------+
# Tot training 1.69 M
# Tot val 1.69 M

# %%
dataset.loadValidationSamples('BSM')
# Out:
# Loading Ato4l (47.7k)
# Loading leptoquark (273.6k)
# Loading hToTauTau (500.0k)
# Loading hChToTauNu (338.5k)

# %% [markdown]
# ## Define the model

# %%
class AEDenseNet(nn.Module):
    def __init__(self, N_part, N_features, dim_hidden, dim_latent, verbose = False):
        super(AEDenseNet, self).__init__()
        self.verbose = verbose
        
        self.No = N_part
        self.p = N_features
        self.Nk = dim_latent
        
        self.encoder_modules = nn.ModuleDict({
            'PhiE': self.build_dense(dim_in=self.p*self.No,
                                   dim_out=self.Nk,
                                   dim_hidden=dim_hidden)
        })
        
        
        self.decoder_modules = nn.ModuleDict({
            'PhiD': self.build_dense(dim_in=self.Nk,
                                   dim_out=(self.p+3)*self.No,
                                   dim_hidden=dim_hidden),
            'ChargeDec': self.build_dense(dim_in=2,
                                   dim_out=3),
            'pdgIdDec': self.build_dense(dim_in=2,
                                   dim_out=5)
        })
        
        
        self.onGPU = False
          
    def build_dense(self, dim_in, dim_out, dim_hidden=0):
        if dim_hidden:
            net = nn.Sequential(
                                nn.Linear(dim_in, dim_hidden),
                                nn.ReLU(),
                                nn.Linear(dim_hidden, dim_hidden),
                                nn.ReLU(),
                                nn.Linear(dim_hidden, dim_out),
                              )
        else:
            d_avg = int(0.5*(dim_in + dim_out))
            net = nn.Sequential(
                                nn.Linear(dim_in, d_avg),
                                nn.ReLU(),
                                nn.Linear(d_avg, dim_out),
                              )
        return net
        
    def encode(self, x):
        z_raw = self.encoder_modules['PhiE'](x.contiguous().view(-1, self.p*self.No))
        z = F.hardtanh(z_raw, min_val=-5, max_val=5)
        return z
    
    def decode(self, z):
        x_raw = self.decoder_modules['PhiD'](z).view(-1, self.No, self.p+3)
        
        # --- Formatting x ----
        # pt
        pt = 1. + F.elu(x_raw[:,:,0]).view(-1, self.No, 1)
        sig_pt = 1. + 1e-6 + F.elu(x_raw[:,:,1]).view(-1, self.No, 1)
        # eta
        eta = F.hardtanh(x_raw[:,:,2], min_val=-5, max_val=5).view(-1, self.No, 1)
        sig_eta = 1. + 1e-6 + F.elu(x_raw[:,:,3]).view(-1, self.No, 1)
        # phi
        phi = torch.fmod(torch.abs(x_raw[:,:,4]), 6.2831853072).view(-1, self.No, 1) - 3.14159265359
        sig_phi = 1. + 1e-6 + F.elu(x_raw[:,:,5]).view(-1, self.No, 1)
        # charge
        charge_cat = F.softmax(self.decoder_modules['ChargeDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 3)
        # pId
        pId_cat = F.softmax(self.decoder_modules['pdgIdDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 5)
        
        x = torch.cat((pt, eta, phi, sig_pt, sig_eta, sig_phi, charge_cat, pId_cat), 2)
        return x
        
    
    def forward(self, x):
        z = self.encode(x)
        x_prime = self.decode(z)
        return x_prime
    
    def initWeights(self):
        def weights_init(M):
            if hasattr(M, 'weight'):
                nn.init.xavier_normal_(M.weight.data)
        
        self.apply(weights_init)
    
    def useGPU(self, N_GPU=1):
        if torch.cuda.is_available():
            print('Current device: {} ({} available)'.format(torch.cuda.current_device(), 
                                                             torch.cuda.device_count()))
            self.N_GPU = N_GPU
            torch.cuda.empty_cache()
            self.cuda(N_GPU)
            gpustat.print_gpustat()
            
            self.onGPU = True
        else: 
            print('GPU not available')

# %%
Latent_dimension = int(0.8*dataset.inputs.shape[1])
Hidden_dimension = int(0.7*(Latent_dimension + dataset.inputs.shape[1]*dataset.inputs.shape[2]))

model = AEDenseNet(
                   N_part=dataset.inputs.shape[1],
                   N_features=dataset.inputs.shape[2],
                   dim_hidden=Hidden_dimension,
                   dim_latent=Latent_dimension
                  )

print(model)
trainablePars = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('\nTrainable parameters:', trainablePars)

# model.initWeights()
# Out:
# AEDenseNet(
#   (encoder_modules): ModuleDict(
#     (PhiE): Sequential(
#       (0): Linear(in_features=100, out_features=81, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=81, out_features=81, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=81, out_features=16, bias=True)
#     )
#   )
#   (decoder_modules): ModuleDict(
#     (ChargeDec): Sequential(
#       (0): Linear(in_features=2, out_features=2, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=2, out_features=3, bias=True)
#     )
#     (PhiD): Sequential(
#       (0): Linear(in_features=16, out_features=81, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=81, out_features=81, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=81, out_features=160, bias=True)
#     )
#     (pdgIdDec): Sequential(
#       (0): Linear(in_features=2, out_features=3, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=3, out_features=5, bias=True)
#     )
#   )
# )
#
# Trainable parameters: 37318

# %%
model.useGPU(1)
# Out:
# Current device: 0 (8 available)
# imperium-sm.hep.caltech.edu  Sun Jul  7 22:22:29 2019
# [0] GeForce GTX 1080 | 44'C,  10 % |   720 /  8119 MB | ocerri(709M)
# [1] GeForce GTX 1080 | 25'C,   4 % |   468 /  8119 MB | ocerri(457M)
# [2] GeForce GTX 1080 | 26'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 21'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 25'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [6] GeForce GTX 1080 | 24'C,   0 % |    11 /  8119 MB |
# [7] GeForce GTX 1080 | 25'C,   0 % |    11 /  8119 MB |

# %% [markdown]
# ## Loss

# %%
def criterion(x_in, x_out, reduction='mean'):
    # Gaussian
    out_gauss = torch.pow((x_in[:,:,:3] - x_out[:,:,:3])/ x_out[:,:,3:6], 2) + torch.log(x_out[:,:,3:6])
    out = torch.sum(out_gauss, dim=2)
    
    #Cat cross entropy charge
    aux = torch.log(x_out[:,:,6:9]).view(-1, 3)
    aux = F.nll_loss(aux, 1+x_in[:,:,3].view(-1).long(), reduction='none')
    out += aux.view(-1, x_in.shape[1])
    
    #Cat cross entropy pId
    aux = torch.log(x_out[:,:,9:14]).view(-1, 5)
    out += F.nll_loss(aux, x_in[:,:,4].view(-1).long(), reduction='none').view(-1, x_in.shape[1])
    
    out_per_evt = torch.sum(out, dim=1)
    
    if reduction == 'mean':
        return torch.mean(out_per_evt)
    elif reduction == 'none':
        return out_per_evt
    else:
        raise

# %% [markdown]
# ## Training

# %%
training_params = {'batch_size': 10000,
                   'shuffle': True,
                   'num_workers': 3
                  }

max_epochs = 500

eval_params = {'batch_size': 50000,
               'num_workers': 3
              }

# %%
# torch.autograd.set_detect_anomaly(True);

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 
                              mode='min',
                              factor=0.3,
                              patience=3,
                              verbose=1,
                              threshold=1e-4,
                              cooldown=2,
                              min_lr=1e-7
                             )

# Early stopping
earlyStopping = EarlyStopping(patient=10)

# %%
train_loss = []
BSM_eff = {'ep': []}
for n in dataset.BSM_names:
    BSM_eff[n] = []

loss_history = {'train': [], 'val': []}
optimizer.zero_grad()
try:
    for epoch in range(max_epochs):
        batch_loss = []

        #### ---- Training ---- ####
        model.train()
        dataset.charge(dataset.SMMix_train)
        train_data_iter = torch.utils.data.DataLoader(dataset, **training_params)
        pb = ProgressBar(len(train_data_iter), percentPrecision=5, headLabel='Epoch {}: '.format(epoch))
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)

            x_prime = model(local_x)        
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid loss!!!')
                raise LossNAN
            batch_loss.append(loss.item())

            tail_label = 'Loss: {:2.2e}'.format(loss.item())
            if len(loss_history['train']) > 0:
                tail_label += ' ({:2.2e})'.format(loss.item() - loss_history['train'][-1][-1])
            pb.show(len(batch_loss)-1, tail_label=tail_label)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        model.eval()
        aux_loss = 0
        N_batches = 0
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            aux_loss += loss.item()
            N_batches += 1
        batch_loss.append(aux_loss/N_batches)

        printout = 'Loss: {:2.2e}'.format(batch_loss[-1])
        if len(loss_history['train']) > 0:
            printout += ' - Delta: {:2.2e}'.format(batch_loss[-1] - loss_history['train'][-1][-1])
        if len(loss_history['train']) > 1:
            d2L_de2 = batch_loss[-1] - 2*loss_history['train'][-1][-1] + loss_history['train'][-2][-1]
            printout +=' - Trend: {:2.2e}'.format(d2L_de2)
        print(printout)

        loss_history['train'].append(batch_loss)

        #### ---- Validation ---- ####
        dataset.charge(dataset.SMMix_val)
        val_data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
        aux_loss = 0
        N_batches = 0
        for local_x, _ in val_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid loss!!!')
                raise LossNAN
            aux_loss += loss.item()
            N_batches += 1
        loss_history['val'].append(aux_loss/N_batches)
        printout = 'Val Loss: {:2.2e}'.format(loss_history['val'][-1])
        print(printout)
        if epoch > 0:
            if loss_history['val'][-1] < np.min(loss_history['val']):
                print('[INFO]: Saving best model')
                torch.save(model.state_dict(), 'data/model_state_dict_dAE_v'+AEversion+'_best.pkl')

        print('')
        if not earlyStopping.check(loss_history['val'][-1]):
            break

        scheduler.step(batch_loss[-1])

        #### ---- Anomaly Detection monitor ---- ####
        if epoch%3 == 0:
            print('------------ Anomaly Detection monitor ------------')
            BSM_eff['ep'].append(epoch)
            dataset.loss['SMMix'] = np.zeros((0))

            pb = ProgressBar(len(val_data_iter), percentPrecision=5, headLabel='SM Mix: ')
            for i, (local_x, _) in enumerate(val_data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss['SMMix'] = np.concatenate((dataset.loss['SMMix'], loss))

            p_SM = np.logspace(base=10, start=-5, stop=-3, num=3)
            if not 'p_SM' in BSM_eff.keys():
                BSM_eff['p_SM'] = p_SM
            q_SM = np.quantile(dataset.loss['SMMix'], 1-p_SM)

            table = PrettyTable(['SM Mix'] + list(map(lambda x: '{:1.2e}'.format(x), p_SM)))

            for n in dataset.BSM_names:
                dataset.loss[n] = np.zeros((0))

                dataset.charge(dataset.valSamples[n])
                data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
                pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
                for i, (local_x, _) in enumerate(data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss[n] = np.concatenate((dataset.loss[n], loss))

                out = dataset.loss[n] > np.atleast_2d(q_SM).T
                p_BSM = np.float64(np.sum(out, axis=1, dtype=np.float128)/dataset.loss[n].shape[0])
                BSM_eff[n].append(p_BSM)

                table.add_row([n] + list(map(lambda x: '{:1.2e}'.format(x), p_BSM)))
            print(table)                
            print('---------------------------------------------------\n\n')

    model.eval()
    torch.save(model.state_dict(), 'data/model_state_dict_dAE_v'+AEversion+'.pkl');
except LossNAN:
    print ('\n\nModel ended up nan. Recovering best model\n')
    model.load_state_dict(torch.load('data/model_state_dict_dAE_v'+AEversion+'_best.pkl'))
# Out:
# Epoch 0: [####################]  100% - Tot. time: 7.7 s
# Loss: 7.10e+01
# Val Loss: 7.12e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 8.38e-05 | 1.22e-03 | 1.78e-02 |
# | leptoquark | 6.21e-05 | 1.06e-03 | 1.83e-02 |
# | hToTauTau  | 4.16e-04 | 4.91e-03 | 4.30e-02 |
# | hChToTauNu | 1.00e-03 | 1.01e-02 | 6.80e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 1: [####################]  100% - Tot. time: 7.9 s
# Loss: 8.27e+01 - Delta: 1.17e+01
# Val Loss: 8.28e+01
#
# Epoch 2: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 5.58e+01 - Delta: -2.70e+01 - Trend: -3.87e+01
# Val Loss: 5.58e+01
#
# Epoch 3: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 5.14e+01 - Delta: -4.31e+00 - Trend: 2.27e+01
# Val Loss: 5.15e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 9.64e-04 | 6.67e-03 | 4.36e-02 |
# | leptoquark | 1.39e-04 | 1.38e-03 | 1.26e-02 |
# | hToTauTau  | 3.18e-04 | 2.51e-03 | 2.01e-02 |
# | hChToTauNu | 7.15e-04 | 4.62e-03 | 3.20e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 4: [####################]  100% - Tot. time: 10.0 s
# [INFO]: Saving best model
# Loss: 4.89e+01 - Delta: -2.58e+00 - Trend: 1.73e+00
# Val Loss: 4.89e+01
#
# Epoch 5: [####################]  100% - Tot. time: 7.5 s
# Loss: 5.07e+01 - Delta: 1.81e+00 - Trend: 4.39e+00
# Val Loss: 5.07e+01
#
# Epoch 6: [####################]  100% - Tot. time: 8.0 s
# [INFO]: Saving best model
# Loss: 4.76e+01 - Delta: -3.12e+00 - Trend: -4.93e+00
# Val Loss: 4.76e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##########]  100% - Tot. time: 2.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.2 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 6.29e-04 | 1.27e-02 | 8.42e-02 |
# | leptoquark | 2.01e-04 | 2.46e-03 | 2.32e-02 |
# | hToTauTau  | 4.28e-04 | 3.99e-03 | 3.36e-02 |
# | hChToTauNu | 6.59e-04 | 6.51e-03 | 5.29e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 7: [####################]  100% - Tot. time: 8.2 s
# [INFO]: Saving best model
# Loss: 4.31e+01 - Delta: -4.50e+00 - Trend: -1.38e+00
# Val Loss: 4.31e+01
#
# Epoch 8: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 4.30e+01 - Delta: -1.10e-01 - Trend: 4.39e+00
# Val Loss: 4.30e+01
#
# Epoch 9: [####################]  100% - Tot. time: 7.7 s
# [INFO]: Saving best model
# Loss: 4.06e+01 - Delta: -2.34e+00 - Trend: -2.23e+00
# Val Loss: 4.07e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 10.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.05e-04 | 5.91e-03 | 6.03e-02 |
# | leptoquark | 4.75e-05 | 1.46e-03 | 1.61e-02 |
# | hToTauTau  | 2.68e-04 | 3.89e-03 | 2.93e-02 |
# | hChToTauNu | 5.20e-04 | 7.69e-03 | 4.68e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 10: [####################]  100% - Tot. time: 7.8 s
# [INFO]: Saving best model
# Loss: 3.63e+01 - Delta: -4.28e+00 - Trend: -1.94e+00
# Val Loss: 3.64e+01
#
# Epoch 11: [####################]  100% - Tot. time: 7.5 s
# Loss: 3.85e+01 - Delta: 2.13e+00 - Trend: 6.41e+00
# Val Loss: 3.85e+01
#
# Epoch 12: [####################]  100% - Tot. time: 7.6 s
# Loss: 4.06e+01 - Delta: 2.11e+00 - Trend: -1.79e-02
# Val Loss: 4.06e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 9.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.31e-04 | 4.40e-03 | 6.63e-02 |
# | leptoquark | 8.41e-05 | 1.29e-03 | 1.87e-02 |
# | hToTauTau  | 4.06e-04 | 4.21e-03 | 3.80e-02 |
# | hChToTauNu | 9.90e-04 | 8.36e-03 | 5.77e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 13: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 3.45e+01 - Delta: -6.11e+00 - Trend: -8.23e+00
# Val Loss: 3.45e+01
#
# Epoch 14: [####################]  100% - Tot. time: 7.6 s
# Loss: 3.50e+01 - Delta: 4.96e-01 - Trend: 6.61e+00
# Val Loss: 3.50e+01
#
# Epoch 15: [####################]  100% - Tot. time: 7.5 s
# [INFO]: Saving best model
# Loss: 3.15e+01 - Delta: -3.45e+00 - Trend: -3.95e+00
# Val Loss: 3.16e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.5 s
# hToTauTau: [##########]  100% - Tot. time: 2.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.89e-04 | 5.72e-03 | 5.95e-02 |
# | leptoquark | 5.12e-05 | 1.24e-03 | 1.60e-02 |
# | hToTauTau  | 2.44e-04 | 3.57e-03 | 2.97e-02 |
# | hChToTauNu | 5.70e-04 | 6.76e-03 | 4.73e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 16: [####################]  100% - Tot. time: 7.7 s
# Loss: 3.37e+01 - Delta: 2.14e+00 - Trend: 5.59e+00
# Val Loss: 3.37e+01
#
# Epoch 17: [####################]  100% - Tot. time: 7.8 s
# Loss: 3.53e+01 - Delta: 1.68e+00 - Trend: -4.64e-01
# Val Loss: 3.54e+01
#
# Epoch 18: [####################]  100% - Tot. time: 9.4 s
# Loss: 3.53e+01 - Delta: 1.51e-02 - Trend: -1.66e+00
# Val Loss: 3.54e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.26e-04 | 3.52e-03 | 5.45e-02 |
# | leptoquark | 2.56e-05 | 7.71e-04 | 1.52e-02 |
# | hToTauTau  | 2.10e-04 | 2.98e-03 | 2.99e-02 |
# | hChToTauNu | 5.44e-04 | 5.81e-03 | 4.72e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 19: [####################]  100% - Tot. time: 7.5 s
# Loss: 3.24e+01 - Delta: -2.94e+00 - Trend: -2.96e+00
# Val Loss: 3.24e+01
#
# Epoch    19: reducing learning rate of group 0 to 3.0000e-04.
# Epoch 20: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 2.88e+01 - Delta: -3.63e+00 - Trend: -6.85e-01
# Val Loss: 2.88e+01
#
# Epoch 21: [####################]  100% - Tot. time: 8.8 s
# [INFO]: Saving best model
# Loss: 2.76e+01 - Delta: -1.18e+00 - Trend: 2.44e+00
# Val Loss: 2.77e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 8.38e-05 | 3.73e-03 | 5.06e-02 |
# | leptoquark | 2.19e-05 | 7.71e-04 | 1.43e-02 |
# | hToTauTau  | 1.22e-04 | 2.36e-03 | 2.75e-02 |
# | hChToTauNu | 3.37e-04 | 4.20e-03 | 4.21e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 22: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 2.71e+01 - Delta: -5.18e-01 - Trend: 6.63e-01
# Val Loss: 2.71e+01
#
# Epoch 23: [####################]  100% - Tot. time: 7.7 s
# Loss: 2.76e+01 - Delta: 5.51e-01 - Trend: 1.07e+00
# Val Loss: 2.77e+01
#
# Epoch 24: [####################]  100% - Tot. time: 7.9 s
# [INFO]: Saving best model
# Loss: 2.70e+01 - Delta: -6.75e-01 - Trend: -1.23e+00
# Val Loss: 2.70e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.05e-04 | 3.37e-03 | 5.01e-02 |
# | leptoquark | 2.19e-05 | 8.99e-04 | 1.49e-02 |
# | hToTauTau  | 1.80e-04 | 2.83e-03 | 2.81e-02 |
# | hChToTauNu | 4.55e-04 | 5.12e-03 | 4.38e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 25: [####################]  100% - Tot. time: 7.7 s
# [INFO]: Saving best model
# Loss: 2.68e+01 - Delta: -1.92e-01 - Trend: 4.83e-01
# Val Loss: 2.68e+01
#
# Epoch 26: [####################]  100% - Tot. time: 7.8 s
# Loss: 3.77e+01 - Delta: 1.10e+01 - Trend: 1.12e+01
# Val Loss: 3.78e+01
#
# Epoch 27: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.88e+01 - Delta: -8.91e+00 - Trend: -1.99e+01
# Val Loss: 2.89e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# [INFO]: Saving best model
# Loss: 2.38e+01 - Delta: -9.46e-01 - Trend: -1.28e+00
# Val Loss: 2.39e+01
#
# Epoch 32: [####################]  100% - Tot. time: 8.4 s
# [INFO]: Saving best model
# Loss: 2.27e+01 - Delta: -1.10e+00 - Trend: -1.57e-01
# Val Loss: 2.28e+01
#
# Epoch 33: [####################]  100% - Tot. time: 7.7 s
# Loss: 2.36e+01 - Delta: 8.99e-01 - Trend: 2.00e+00
# Val Loss: 2.37e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 6.29e-05 | 1.45e-03 | 3.54e-02 |
# | leptoquark | 2.19e-05 | 5.67e-04 | 1.14e-02 |
# | hToTauTau  | 1.82e-04 | 1.95e-03 | 2.33e-02 |
# | hChToTauNu | 3.99e-04 | 3.44e-03 | 3.66e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 34: [####################]  100% - Tot. time: 7.7 s
# [INFO]: Saving best model
# Loss: 2.26e+01 - Delta: -9.85e-01 - Trend: -1.88e+00
# Val Loss: 2.27e+01
#
# Epoch 35: [####################]  100% - Tot. time: 7.8 s
# [INFO]: Saving best model
# Loss: 2.11e+01 - Delta: -1.58e+00 - Trend: -5.92e-01
# Val Loss: 2.11e+01
#
# Epoch 36: [####################]  100% - Tot. time: 7.9 s
# Loss: 3.37e+01 - Delta: 1.26e+01 - Trend: 1.42e+01
# Val Loss: 3.37e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 6.29e-05 | 8.59e-04 | 2.37e-02 |
# | leptoquark | 1.83e-05 | 4.46e-04 | 8.20e-03 |
# | hToTauTau  | 1.54e-04 | 1.45e-03 | 1.71e-02 |
# | hChToTauNu | 3.69e-04 | 2.65e-03 | 2.76e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 37: [####################]  100% - Tot. time: 9.9 s
# Loss: 4.21e+01 - Delta: 8.41e+00 - Trend: -4.20e+00
# Val Loss: 4.21e+01
#
# Epoch 38: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.66e+01 - Delta: -1.55e+01 - Trend: -2.39e+01
# Val Loss: 2.66e+01
#
# Epoch 39: [####################]  100% - Tot. time: 7.7 s
# [INFO]: Saving best model
# Loss: 2.09e+01 - Delta: -5.65e+00 - Trend: 9.87e+00
# Val Loss: 2.10e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.5 s
# hToTauTau: [##########]  100% - Tot. time: 2.5 s
# hChToTauNu: [#######]  100% - Tot. time: 1.4 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 7.97e-04 | 2.70e-02 |
# | leptoquark | 1.10e-05 | 4.17e-04 | 9.70e-03 |
# | hToTauTau  | 1.04e-04 | 1.10e-03 | 1.92e-02 |
# | hChToTauNu | 2.90e-04 | 1.96e-03 | 3.04e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 40: [####################]  100% - Tot. time: 8.6 s
# Loss: 2.15e+01 - Delta: 6.10e-01 - Trend: 6.26e+00
# Val Loss: 2.16e+01
#
# Epoch 41: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.20e+01 - Delta: 4.85e-01 - Trend: -1.25e-01
# Val Loss: 2.21e+01
#
# Epoch 42: [####################]  100% - Tot. time: 7.5 s
# [INFO]: Saving best model
# Loss: 2.07e+01 - Delta: -1.32e+00 - Trend: -1.80e+00
# Val Loss: 2.07e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 10.1 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 6.29e-05 | 9.01e-04 | 3.02e-02 |
# | leptoquark | 1.83e-05 | 4.53e-04 | 1.09e-02 |
# | hToTauTau  | 1.18e-04 | 1.29e-03 | 2.17e-02 |
# | hChToTauNu | 3.01e-04 | 2.20e-03 | 3.41e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 43: [####################]  100% - Tot. time: 7.8 s
# Loss: 2.13e+01 - Delta: 5.71e-01 - Trend: 1.89e+00
# Val Loss: 2.13e+01
#
# Epoch 44: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 2.05e+01 - Delta: -7.91e-01 - Trend: -1.36e+00
# Val Loss: 2.05e+01
#
# Epoch 45: [####################]  100% - Tot. time: 7.6 s
# [INFO]: Saving best model
# Loss: 2.04e+01 - Delta: -4.21e-02 - Trend: 7.49e-01
# Val Loss: 2.05e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 9.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 8.38e-05 | 1.72e-03 | 3.84e-02 |
# | leptoquark | 2.56e-05 | 6.73e-04 | 1.33e-02 |
# | hToTauTau  | 2.06e-04 | 2.05e-03 | 2.68e-02 |
# | hChToTauNu | 4.28e-04 | 3.43e-03 | 4.15e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 46: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.41e+01 - Delta: 3.71e+00 - Trend: 3.75e+00
# Val Loss: 2.42e+01
#
# Epoch 47: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.23e+01 - Delta: -1.84e+00 - Trend: -5.54e+00
# Val Loss: 2.23e+01
#
# Epoch 48: [####################]  100% - Tot. time: 7.6 s
# Loss: 4.06e+01 - Delta: 1.83e+01 - Trend: 2.01e+01
# Val Loss: 4.06e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.10e-05 | 8.80e-04 | 1.72e-02 |
# | leptoquark | 7.31e-06 | 2.67e-04 | 5.34e-03 |
# | hToTauTau  | 5.00e-05 | 9.06e-04 | 1.23e-02 |
# | hChToTauNu | 1.62e-04 | 1.53e-03 | 1.98e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 49: [####################]  100% - Tot. time: 7.7 s
# [INFO]: Saving best model
# Loss: 1.98e+01 - Delta: -2.07e+01 - Trend: -3.90e+01
# Val Loss: 1.99e+01
#
# Epoch 50: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.08e+01 - Delta: 9.54e-01 - Trend: 2.17e+01
# Val Loss: 2.08e+01
#
# Epoch 51: [####################]  100% - Tot. time: 7.8 s
# [INFO]: Saving best model
# Loss: 1.84e+01 - Delta: -2.39e+00 - Trend: -3.35e+00
# Val Loss: 1.85e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 3.65e-03 | 4.74e-02 |
# | leptoquark | 1.10e-05 | 8.63e-04 | 1.49e-02 |
# | hToTauTau  | 8.80e-05 | 2.20e-03 | 2.92e-02 |
# | hChToTauNu | 1.83e-04 | 3.43e-03 | 4.46e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 52: [####################]  100% - Tot. time: 7.6 s
# Loss: 2.01e+01 - Delta: 1.65e+00 - Trend: 4.04e+00
# Val Loss: 2.01e+01
#
# Epoch 53: [####################]  100% - Tot. time: 7.7 s
# Loss: 1.95e+01 - Delta: -5.22e-01 - Trend: -2.17e+00
# Val Loss: 1.96e+01
#
# Epoch 54: [####################]  100% - Tot. time: 10.4 s
# Loss: 2.00e+01 - Delta: 5.11e-01 - Trend: 1.03e+00
# Val Loss: 2.01e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 8.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.5 s
# hToTauTau: [##########]  100% - Tot. time: 2.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.72e-04 | 6.73e-03 | 5.55e-02 |
# | leptoquark | 8.77e-05 | 1.44e-03 | 1.63e-02 |
# | hToTauTau  | 2.12e-04 | 2.96e-03 | 3.05e-02 |
# | hChToTauNu | 3.84e-04 | 4.61e-03 | 4.68e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 55: [#######-------------]  37% - ETA:    5 s   Loss: 1.81e+01 (-1.90e+00)Invalid loss!!!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-1ccab9fa22bf> in <module>
#      22         if np.isnan(loss.item()) or np.isinf(loss.item()):
#      23             print('Invalid loss!!!')
# ---> 24             raise
#      25         batch_loss.append(loss.item())
#      26
#
# RuntimeError: No active exception to reraise

# %%
model.load_state_dict(torch.load('data/model_state_dict_dAE_v'+AEversion+'_best.pkl'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
x_prime
# Out:
# tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:1',
#        grad_fn=<CatBackward>)

# %%
for param in model.parameters():
  print(param.data)
# Out:
# tensor([[    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [ 0.0384,  0.0017,  0.0099,  ..., -0.0082,  0.0053,  0.0541],
#         ...,
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [-0.0483,  0.0512,  0.0005,  ...,  0.0097,  0.0069,  0.0435],
#         [-0.0997, -0.0599, -0.0324,  ..., -0.0520,  0.0302, -0.0627]],
#        device='cuda:1')
# tensor([    nan,     nan,  0.0590,     nan, -0.0530,  0.1303,     nan,     nan,
#             nan,     nan,  0.0478, -0.0292,  0.0077,  0.0848,     nan,  0.1254,
#             nan,  0.1912,     nan,     nan,  0.1348,  0.1637,     nan,  0.0413,
#         -0.0808, -0.0080, -0.0880,     nan,  0.1546,     nan, -0.0412,  0.1891,
#          0.1128,  0.1054,  0.1954, -0.0182,     nan,  0.0683,     nan,  0.1632,
#          0.0376,     nan,     nan,     nan,     nan,  0.0397,     nan,     nan,
#         -0.0878,     nan,     nan,  0.0327,  0.0866,     nan,  0.1316,     nan,
#             nan,     nan,  0.1533, -0.0362, -0.0074,     nan, -0.0392,     nan,
#          0.1686,     nan,     nan,     nan,     nan,     nan, -0.0634, -0.0764,
#          0.0860,     nan,     nan,     nan,     nan,     nan,     nan,  0.1035,
#          0.0398], device='cuda:1')
# tensor([[    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         ...,
#         [-0.0172, -0.1225,  0.0849,  ...,  0.0748, -0.0309,  0.0141],
#         [ 0.0568, -0.0545,  0.0644,  ...,  0.0163,  0.1026, -0.0515],
#         [-0.0119, -0.0118, -0.0906,  ..., -0.0233,  0.0200, -0.0574]],
#        device='cuda:1')
# tensor([    nan,     nan,     nan, -0.0462,  0.0396,     nan,  0.0562, -0.0268,
#          0.0433,     nan,     nan,  0.1484,     nan,     nan, -0.0070,     nan,
#             nan,     nan,  0.0934, -0.0118,     nan, -0.0468, -0.0817,     nan,
#          0.0692,     nan, -0.0579,     nan,     nan,     nan,     nan, -0.0173,
#          0.1234,     nan, -0.0601,  0.0217, -0.0171,     nan, -0.0610,     nan,
#             nan,  0.0188, -0.0751,  0.0381,     nan,  0.0643,     nan,     nan,
#         -0.1017,     nan,  0.0291,     nan, -0.0385, -0.0227,  0.1183, -0.0620,
#             nan,  0.0013,     nan,     nan, -0.0269,     nan,     nan,     nan,
#         -0.1082, -0.0537,     nan,  0.0725, -0.0432, -0.0494,  0.0638,     nan,
#         -0.1150, -0.0219,     nan,  0.0890,  0.0183,     nan, -0.0558,  0.0226,
#          0.0186], device='cuda:1')
# tensor([[ 0.2636, -0.1319,  0.1285,  ..., -0.1175,  0.0213, -0.0611],
#         [ 0.0046, -0.1483, -0.1489,  ..., -0.0064, -0.0135, -0.1229],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         ...,
#         [-0.0141, -0.0757, -0.1038,  ...,  0.0190, -0.0459, -0.1091],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [-0.0421, -0.0138, -0.1045,  ...,  0.0941, -0.0402,  0.0005]],
#        device='cuda:1')
# tensor([ 0.0067, -0.1431,     nan,     nan, -0.0013, -0.1377,     nan,     nan,
#             nan,  0.0130,     nan, -0.0601,     nan,  0.1084,     nan,  0.0069],
#        device='cuda:1')
# tensor([[-0.6438, -0.0287],
#         [-0.5612,  0.5737]], device='cuda:1')
# tensor([ 1.4941, -0.3329], device='cuda:1')
# tensor([[-0.4347,  0.3576],
#         [ 1.1199, -0.5611],
#         [-0.5238,  0.3567]], device='cuda:1')
# tensor([ 1.0683, -1.5747,  1.2580], device='cuda:1')
# tensor([[-0.0021,  0.1450,  0.1984,  ...,  0.1321, -0.0051,  0.1140],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         ...,
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan]],
#        device='cuda:1')
# tensor([-0.0471,     nan,     nan,     nan,     nan,  0.1419, -0.0312,     nan,
#         -0.2301, -0.0372,  0.1888,     nan,     nan,     nan,     nan,     nan,
#          0.1881,  0.1734,     nan,     nan,     nan,     nan,  0.0329,     nan,
#             nan,  0.1551,     nan,  0.1024, -0.0842,     nan, -0.1063, -0.1529,
#         -0.1367,  0.1997,     nan,     nan,     nan, -0.1598, -0.2133,     nan,
#             nan,  0.0961,     nan,     nan,  0.2250,     nan,     nan, -0.0150,
#             nan,     nan,     nan, -0.0727,  0.0871,  0.2609,     nan,  0.0763,
#          0.0424, -0.0105,  0.0606,     nan, -0.0717,     nan,     nan,     nan,
#             nan,     nan,     nan,     nan,     nan,     nan, -0.0915,     nan,
#             nan,     nan,     nan,     nan,     nan,  0.0500,     nan,     nan,
#             nan], device='cuda:1')
# tensor([[-0.0051, -0.1061, -0.0383,  ..., -0.0113,  0.0536,  0.1102],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [-0.0655,  0.1004,  0.1062,  ...,  0.0536,  0.0998, -0.0925],
#         ...,
#         [ 0.1419,  0.0677,  0.0342,  ...,  0.0686,  0.1013, -0.1121],
#         [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#         [ 0.0142, -0.1012, -0.0135,  ...,  0.0040,  0.0521, -0.0193]],
#        device='cuda:1')
# tensor([ 0.0272,     nan, -0.0111, -0.0423,     nan,     nan,     nan,     nan,
#             nan, -0.0203,     nan, -0.1065,     nan,     nan,     nan, -0.0495,
#             nan,     nan,     nan,     nan,     nan, -0.1348,  0.0789,     nan,
#          0.0769,     nan, -0.0400, -0.0125,     nan,  0.0302,     nan,     nan,
#          0.0377,     nan,     nan,     nan, -0.0374,     nan,     nan,     nan,
#         -0.1303, -0.0955,  0.0777,  0.1094,     nan,  0.0994,  0.0277,  0.0718,
#             nan,  0.0165,     nan,     nan, -0.0848, -0.0904, -0.1355,     nan,
#             nan,  0.0265,     nan, -0.0411,     nan,     nan,     nan,     nan,
#             nan,     nan, -0.0644,     nan,  0.1055,     nan,  0.0521, -0.0497,
#          0.0066, -0.0466,     nan, -0.0743,     nan,     nan, -0.0073,     nan,
#         -0.1167], device='cuda:1')
# tensor([[-0.0182,  0.3293,  0.0646,  ...,  0.0771,  0.3146, -0.1195],
#         [ 0.0177,  0.1204, -0.0562,  ..., -0.0245,  0.0881,  0.0443],
#         [ 0.0700,  0.1116,  0.2315,  ..., -0.6567,  0.5625,  0.0228],
#         ...,
#         [-0.0504, -0.0397,  0.0587,  ..., -0.0252,  0.0106,  0.0990],
#         [ 0.0450, -0.0823,  0.1232,  ...,  0.0210, -0.2263, -0.0493],
#         [ 0.0578, -0.1027, -0.1166,  ..., -0.1865, -0.3174,  0.0189]],
#        device='cuda:1')
# tensor([-0.0243, -0.0567,  0.0069, -0.0032,  0.1455,  0.1038,     nan,     nan,
#          0.0263, -0.1382, -0.0135, -0.0487, -0.0787, -0.0282, -0.0216,  0.2230,
#          0.0084,  0.0865,  0.0855, -0.0369,  0.0442, -0.0402,  0.1086,  0.0759,
#         -0.0771, -0.0581, -0.0141, -0.0832, -0.0006, -0.0380, -0.0024, -0.2559,
#         -0.0904, -0.1155,  0.0238,  0.0507, -0.0615, -0.0829, -0.0884, -0.1171,
#          0.0402, -0.1765, -0.0336,  0.0409,  0.0492, -0.0737, -0.0208, -0.2479,
#          0.0074, -0.0701,  0.1530,  0.0309, -0.0728,  0.1021,  0.0733, -0.1293,
#          0.0171, -0.0609,  0.1136,  0.0033,  0.0531,  0.0739, -0.0972, -0.1999,
#          0.0660, -0.0501,  0.0315, -0.0769,  0.0746, -0.0798, -0.0257, -0.1790,
#          0.0899, -0.1037,  0.0896, -0.0198,  0.0460,  0.0840,  0.0839, -0.1242,
#         -0.1245, -0.2097, -0.0386,  0.1197, -0.0808,  0.0321, -0.0374, -0.1379,
#         -0.0245, -0.2027,  0.0381,  0.0094,  0.0239,  0.0903, -0.0373, -0.2636,
#          0.0352, -0.1083,  0.2188,  0.0579, -0.0174, -0.0735, -0.0285, -0.1094,
#          0.0412, -0.2037,  0.0327, -0.0372,  0.0725,  0.0891, -0.0517, -0.2544,
#         -0.0275, -0.1192, -0.0234,  0.0361,  0.0446, -0.0767,  0.0133, -0.2689,
#          0.0144, -0.1749,  0.0444,  0.0205, -0.0251,  0.1133, -0.0128, -0.3032,
#         -0.1383, -0.1578,  0.1571, -0.0588,  0.1171, -0.0805,  0.0020, -0.2603,
#         -0.0817, -0.2237,  0.0323, -0.0370,  0.0546,  0.0494, -0.0981, -0.1615,
#         -0.1099, -0.1693,  0.0108, -0.0707, -0.1089,  0.0513, -0.1534, -0.1522,
#          0.0325, -0.2251,  0.0770,  0.0157,  0.0641,  0.0104, -0.0025, -0.2283],
#        device='cuda:1')
# tensor([[    nan,     nan],
#         [-1.0296, -0.0566],
#         [-0.5281, -1.0408]], device='cuda:1')
# tensor([    nan, -1.1208,  0.1283], device='cuda:1')
# tensor([[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]], device='cuda:1')
# tensor([nan, nan, nan, nan, nan], device='cuda:1')

# %%
loss_history['train'] = np.array(loss_history['train'])
matplotlib.rcParams.update({'font.size': 16})

f = plt.figure(figsize=(12,8))

train_loss_flat = loss_history['train'].flatten()
x = np.arange(1, train_loss_flat.shape[0]+1) * float(loss_history['train'].shape[0])/train_loss_flat.shape[0]
plt.plot(x, train_loss_flat, '-', alpha=0.2, color='darkorange')

x = np.arange(1, loss_history['train'].shape[0]+1)
plt.plot(x, loss_history['train'][:,-1], 'o--', label='Train', color='darkorange')
plt.plot(x, loss_history['val'], '*', label='Validatation', color='darkmagenta')

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')
plt.yscale('log')
plt.ylim(0.9*np.min(train_loss_flat), 1.1*np.max(loss_history['train'][1:, -1]))

f.savefig('plots/TrainingHistory_dAE_v'+AEversion+'.png')

f = open('data/TrainingHistory_dAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(loss_history, f)
f.close()

# %%
f, ax_arr = plt.subplots(2,2, figsize=(12,12))
styles = ['-', '--', ':']
x = BSM_eff['ep']
for i, n in enumerate(dataset.BSM_names):  
    ax = ax_arr[int(i/2),i%2]
    
    BSM_eff[n] = np.array(BSM_eff[n])
    
    for j in range(BSM_eff['p_SM'].shape[0]):
#         ax.plot(x, len(x)*[BSM_eff['p_SM'][j]], color='gray', lw=2, linestyle=styles[j])
        ax.plot(x, BSM_eff[n][:,j], 
                color=dataset.process_colors[n], lw=3, linestyle=styles[j], 
                label=dataset.process_labels[n] + ' @ $\epsilon_{{SM}} = {:1.0e}$'.format(BSM_eff['p_SM'][j]))
        
    ax.set_xlim([0, x[-1]+1])
#     ax.set_ylim([1e-6, 5])
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.grid()
    
    ax.legend(loc='best')
    
f.tight_layout()

f = open('data/AnomalyDetectionHistory_dAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(BSM_eff, f)
f.close()

# %% [markdown]
# # Convergence check

# %%
dataset.charge(dataset.SMMix_val)
x = dataset.inputs
model.eval()
if model.onGPU:
    x_prime = model(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
else:
    x_prime = model(torch.from_numpy(x[:10000])).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000])).cpu().detach().numpy()

# %% [markdown]
# ### Latent space

# %%
for i in range(z.shape[1]):
    x_aux = z[:,i]
    f = plt.figure(i)
    r = (np.min(x_aux), np.max(x_aux))
    plt.hist(x_aux, bins=20, range=r, alpha=0.4, density=True)
    plt.xlabel('$z_{{{}}}$'.format(i))
    dnd.append(f)

# %% [markdown]
# ### Output features

# %%
for i in range(x.shape[2]):
    x_aux = x[:,:,i].flatten()
    if i < 3:
        xp_aux = x_prime[:,:,i].flatten()
    elif i==3:
        xp_aux = np.argmax(x_prime[:,:,6:9], axis=2)
        xp_aux = xp_aux.flatten() - 1
    elif i==4:
        xp_aux = np.argmax(x_prime[:,:,9:14], axis=2).flatten()
        
    f = plt.figure(i)
    r = (min(np.min(x_aux), np.min(xp_aux)), max(np.max(x_aux), np.max(xp_aux)))
    if i == 0:
        r = (0,10)
    plt.hist(x_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.hist(xp_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.xlabel('Particles ' + dataset.feature_names[i])
    plt.yscale('log')
    dnd.append(f)

# %% [markdown]
# # Performance evaluation

# %%
dataset.loadValidationSamples('SM')
# Out:
# Loading Wlnu (1000.0k)
# Loading qcd (570.9k)
# Loading Zll (886.8k)
# Loading ttbar (994.9k)
# SM Mix limiting stat. sample: qcd (0.57M)
# SM validation weights
# [('Wlnu', 0.99999834319526624413), ('qcd', 1.0), ('Zll', 0.12761873894588048826), ('ttbar', 0.0050933672635218982447)]

# %%
model.eval()
for n in dataset.valSamples.keys():
    dataset.loss[n] = np.zeros((0))
    
    dataset.charge(dataset.valSamples[n])
    data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
    pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
    for i, (local_x, _) in enumerate(data_iter):
        pb.show(i)
        if model.onGPU:
            local_x = local_x.cuda(model.N_GPU)
            
        x_prime = model(local_x)
        loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
        dataset.loss[n] = np.concatenate((dataset.loss[n], loss))
# Out:
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##########]  100% - Tot. time: 2.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# Wlnu: [####################]  100% - Tot. time: 4.8 s
# qcd: [############]  100% - Tot. time: 2.2 s
# Zll: [##################]  100% - Tot. time: 4.0 s
# ttbar: [####################]  100% - Tot. time: 4.7 s

# %%
dic_ROC = createROC_curve(dataset)
pickle.dump(dic_ROC, open('data/dAE_v{}_ROC_dic.pkl'.format(AEversion), 'wb'))
# Out:
# CumSum accuracy: 0.9999999999999883757

# %%
f_ROC, ax_arr = plt.subplots(2,2, figsize=(12,12))
for i, n in enumerate(dataset.BSM_names):
    f = open('../data/HLFref1811-10276_loss/VAE_all-in-one_v71_ROC1_dict_{}.pkl'.format(n), 'br')
    dRef = pickle.load(f, encoding='bytes')
    f.close()
    
    ax = ax_arr[int(i/2),i%2]
    ax.plot(dRef[b'eff_SM'], dRef[b'eff_BSM'], label=dataset.process_labels[n] + ' HLF',
            linestyle='--', lw=3, color=dataset.process_colors[n])
    ax.plot(dic_ROC[n]['eff_SM'], dic_ROC[n]['eff_BSM'], label=dataset.process_labels[n] + ' PF',
            linestyle='-', lw=3, color=dataset.process_colors[n])
    ax.plot([0, 1], [0, 1], color='gray', lw=2, linestyle=':')
    ax.set_xlim([1e-6, 1.0])
    ax.set_ylim([1e-6, 1.05])
    ax.set_xlabel('SM efficiency')
    ax.set_ylabel('BSM efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.grid()
    
    ax.legend(loc='lower right')
    
f_ROC.tight_layout()

# %% [markdown]
# ## Latent dimension clustering

# %%
from sklearn.manifold import TSNE

# %%
dataset.encoded = {}

for n in dataset.BSM_names:    
    dataset.charge(dataset.valSamples[n][:10000])
    x_in = torch.Tensor(dataset.inputs)
    if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
    dataset.encoded[n] = model.encode(x_in).cpu().detach().numpy()
    
dataset.charge(dataset.SMMix_val[:10000])
x_in = torch.Tensor(dataset.inputs)
if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
dataset.encoded['SMMix'] = model.encode(x_in).cpu().detach().numpy()

# %%
idx_max = 1000 #np.min(list(map(lambda x: x.shape[0], dataset.encoded.values())))
z_dset = np.zeros((0, model.Nk))

for n in dataset.encoded.keys():
    z_dset = np.concatenate((z_dset, dataset.encoded[n][:idx_max]))
    
z_embedded = TSNE(n_components=2).fit_transform(z_dset)

# %%
f = plt.figure(figsize=(8,8))

for i, n in enumerate(dataset.encoded.keys()):
    aux_z = z_embedded[i*idx_max: (i+1)*idx_max]
    plt.plot(aux_z[:,0], aux_z[:,1], 
             'o',
             color=dataset.process_colors[n], 
             mfc='none',
             label=dataset.process_labels[n])
    
plt.xlabel('Embedded 0')
plt.ylabel('Embedded 1')
plt.legend(loc='best')
f.tight_layout()
