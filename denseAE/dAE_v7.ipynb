# %% [markdown]
# Copy of 6 with less parameters

# %%
AEversion = '7'

# %%
import numpy as np
import os, sys, pickle
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import gpustat
try:
    gpustat.print_gpustat()
except:
    pass
# Out:
# imperium-sm.hep.caltech.edu  Thu Jul 11 06:06:30 2019
# [0] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [1] GeForce GTX 1080 | 24'C,   0 % |  6672 /  8119 MB | ocerri(6661M)
# [2] GeForce GTX 1080 | 27'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 25'C,   0 % |  1582 /  8119 MB | ocerri(1571M)
# [6] GeForce GTX 1080 | 37'C,   0 % |  2794 /  8119 MB | ocerri(2783M)
# [7] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
sys.path.append('../lib')
from progressBar import ProgressBar
from utils import EarlyStopping, createROC_curve, ELU_ProbNorm

# %%
dnd = []

# %% [markdown]
# ## Get the dataset

# %%
from dataLoaders import ParticleDataset

# %%
dataset = ParticleDataset(template='../data/20190708_50part_PtOrder_v2/{}.npy', N_part=50, N_features=5)

# %%
dataset.loadTrainSM(N_train_max=1e7)
dataset.charge(dataset.SMMix_train)
# Out:
# Fetching Wlnu
# Fetching qcd
# Fetching Zll
# Fetching ttbar
# QCD is limiting, using it for both val and split
# Expected 3.38M train
# Expected 3.38M val
#
# Loading Wlnu
# Reloading QCD for validation
# Loading Zll
# Loading ttbar
# +--------+----------+-------+-------+
# | Sample | Evts tot | Train |  Val  |
# +--------+----------+-------+-------+
# |  Wlnu  |  4000k   | 2000k | 2000k |
# |  qcd   |  1166k   | 1142k | 1142k |
# |  Zll   |  1000k   |  226k |  226k |
# | ttbar  |  1000k   |  10k  |  10k  |
# +--------+----------+-------+-------+
# Tot training 3.38 M
# Tot val 3.38 M

# %%
dataset.loadValidationSamples('BSM')
# Out:
# Loading Ato4l (47.7k)
# Loading leptoquark (273.6k)
# Loading hToTauTau (681.8k)
# Loading hChToTauNu (338.5k)

# %% [markdown]
# ## Define the model

# %%
class AEDenseNet(nn.Module):
    def __init__(self, N_part, N_features, dim_hidden, dim_latent, verbose = False):
        super(AEDenseNet, self).__init__()
        self.verbose = verbose
        
        self.No = N_part
        self.p = N_features
        self.Nk = dim_latent
        
        self.encoder_modules = nn.ModuleDict({
            'PhiE': self.build_dense(dim_in=self.p*self.No,
                                   dim_out=self.Nk,
                                   dim_hidden=dim_hidden)
        })
        
        
        self.decoder_modules = nn.ModuleDict({
            'PhiD': self.build_dense(dim_in=self.Nk,
                                   dim_out=(self.p+3)*self.No,
                                   dim_hidden=dim_hidden),
            'ChargeDec': self.build_dense(dim_in=2,
                                   dim_out=3),
            'pdgIdDec': self.build_dense(dim_in=2,
                                   dim_out=5)
        })
        
        
        self.onGPU = False
          
    def build_dense(self, dim_in, dim_out, dim_hidden=0):
        if dim_hidden:
            net = nn.Sequential(
                                nn.Linear(dim_in, dim_hidden),
                                nn.ReLU(),
                                nn.Linear(dim_hidden, dim_hidden),
                                nn.ReLU(),
                                nn.Linear(dim_hidden, dim_out),
                              )
        else:
            d_avg = int(0.5*(dim_in + dim_out))
            net = nn.Sequential(
                                nn.Linear(dim_in, d_avg),
                                nn.ReLU(),
                                nn.Linear(d_avg, dim_out),
                              )
        return net
        
    def encode(self, x):
        z_raw = self.encoder_modules['PhiE'](x.contiguous().view(-1, self.p*self.No))
        z = F.hardtanh(z_raw, min_val=-5, max_val=5)
        return z
    
    def decode(self, z):
        x_raw = self.decoder_modules['PhiD'](z).view(-1, self.No, self.p+3)
        
        # --- Formatting x ----
        # pt
        pt = 1. + F.elu(x_raw[:,:,0]).view(-1, self.No, 1)
        sig_pt = 1. + 1e-6 + F.elu(x_raw[:,:,1]).view(-1, self.No, 1)
        # eta
        eta = F.hardtanh(x_raw[:,:,2], min_val=-5, max_val=5).view(-1, self.No, 1)
        sig_eta = 1. + 1e-6 + F.elu(x_raw[:,:,3]).view(-1, self.No, 1)
        # phi
        phi = torch.fmod(torch.abs(x_raw[:,:,4]), 6.2831853072).view(-1, self.No, 1) - 3.14159265359
        sig_phi = 1. + 1e-6 + F.elu(x_raw[:,:,5]).view(-1, self.No, 1)
        # charge
#         charge_cat = F.softmax(self.decoder_modules['ChargeDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 3)
        charge_cat = ELU_ProbNorm(self.decoder_modules['ChargeDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 3)
        # pId
#         pId_cat = F.softmax(self.decoder_modules['pdgIdDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 5)
        pId_cat = ELU_ProbNorm(self.decoder_modules['pdgIdDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 5)
        
        x = torch.cat((pt, eta, phi, sig_pt, sig_eta, sig_phi, charge_cat, pId_cat), 2)
        return x
        
    
    def forward(self, x):
        z = self.encode(x)
        x_prime = self.decode(z)
        return x_prime
    
    def initWeights(self):
        def weights_init(M):
            if hasattr(M, 'weight'):
                nn.init.xavier_normal_(M.weight.data)
        
        self.apply(weights_init)
    
    def useGPU(self, N_GPU=1):
        if torch.cuda.is_available():
            print('Current device: {} ({} available)'.format(torch.cuda.current_device(), 
                                                             torch.cuda.device_count()))
            os.environ['CUDA_VISIBLE_DEVICES'] = str(N_GPU)
            self.N_GPU = N_GPU
            torch.cuda.empty_cache()
            self.cuda(N_GPU)
            gpustat.print_gpustat()
            
            self.onGPU = True
        else: 
            print('GPU not available')

# %%
Latent_dimension = int(0.4*dataset.inputs.shape[1])
Hidden_dimension = int(0.3*(Latent_dimension + dataset.inputs.shape[1]*dataset.inputs.shape[2]))

model = AEDenseNet(
                   N_part=dataset.inputs.shape[1],
                   N_features=dataset.inputs.shape[2],
                   dim_hidden=Hidden_dimension,
                   dim_latent=Latent_dimension
                  )

print(model)
trainablePars = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('\nTrainable parameters:', trainablePars)

# model.initWeights()
# Out:
# AEDenseNet(
#   (encoder_modules): ModuleDict(
#     (PhiE): Sequential(
#       (0): Linear(in_features=250, out_features=81, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=81, out_features=81, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=81, out_features=20, bias=True)
#     )
#   )
#   (decoder_modules): ModuleDict(
#     (ChargeDec): Sequential(
#       (0): Linear(in_features=2, out_features=2, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=2, out_features=3, bias=True)
#     )
#     (PhiD): Sequential(
#       (0): Linear(in_features=20, out_features=81, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=81, out_features=81, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=81, out_features=400, bias=True)
#     )
#     (pdgIdDec): Sequential(
#       (0): Linear(in_features=2, out_features=3, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=3, out_features=5, bias=True)
#     )
#   )
# )
#
# Trainable parameters: 69800

# %%
model.useGPU(int(AEversion))
# Out:
# Current device: 0 (8 available)
# imperium-sm.hep.caltech.edu  Thu Jul 11 06:07:10 2019
# [0] GeForce GTX 1080 | 24'C,   0 % |    11 /  8119 MB |
# [1] GeForce GTX 1080 | 24'C,   0 % |  6672 /  8119 MB | ocerri(6661M)
# [2] GeForce GTX 1080 | 27'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 24'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 25'C,   0 % |  1582 /  8119 MB | ocerri(1571M)
# [6] GeForce GTX 1080 | 33'C,   0 % |  2794 /  8119 MB | ocerri(2783M)
# [7] GeForce GTX 1080 | 31'C,   2 % |   468 /  8119 MB | ocerri(457M)

# %% [markdown]
# ## Loss

# %%
def criterion(x_in, x_out, reduction='mean'):
    # Gaussian
    out_gauss = torch.pow((x_in[:,:,:3] - x_out[:,:,:3])/ x_out[:,:,3:6], 2) + torch.log(x_out[:,:,3:6])
    out = torch.sum(out_gauss, dim=2)
    
    #Cat cross entropy charge
    aux = torch.log(x_out[:,:,6:9]).view(-1, 3)
    aux = F.nll_loss(aux, 1+x_in[:,:,3].view(-1).long(), reduction='none')
    out += aux.view(-1, x_in.shape[1])
    
    #Cat cross entropy pId
    aux = torch.log(x_out[:,:,9:14]).view(-1, 5)
    out += F.nll_loss(aux, x_in[:,:,4].view(-1).long(), reduction='none').view(-1, x_in.shape[1])
    
    out_per_evt = torch.sum(out, dim=1)
    
    if reduction == 'mean':
        return torch.mean(out_per_evt)
    elif reduction == 'none':
        return out_per_evt
    else:
        raise

# %% [markdown]
# ## Training

# %%
training_params = {'batch_size': 10000,
                   'shuffle': True,
                   'num_workers': 3
                  }

max_epochs = 1000

eval_params = {'batch_size': 50000,
               'num_workers': 3
              }

# %%
# torch.autograd.set_detect_anomaly(True);

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 
                              mode='min',
                              factor=0.3,
                              patience=3,
                              verbose=1,
                              threshold=1e-4,
                              cooldown=2,
                              min_lr=1e-7
                             )

# Early stopping
earlyStopping = EarlyStopping(patient=10)

# %%
train_loss = []
BSM_eff = {'ep': []}
for n in dataset.BSM_names:
    BSM_eff[n] = []

loss_history = {'train': [], 'val': []}
optimizer.zero_grad()
try:
    for epoch in range(max_epochs):
        batch_loss = []

        #### ---- Training ---- ####
        model.train()
        dataset.charge(dataset.SMMix_train)
        train_data_iter = torch.utils.data.DataLoader(dataset, **training_params)
        pb = ProgressBar(len(train_data_iter), percentPrecision=5, headLabel='Epoch {}: '.format(epoch))
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)

            x_prime = model(local_x)        
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid training loss!!!')
                raise NameError('LossNAN')
            batch_loss.append(loss.item())

            tail_label = 'Loss: {:2.2e}'.format(loss.item())
            if len(loss_history['train']) > 0:
                tail_label += ' ({:2.2e})'.format(loss.item() - loss_history['train'][-1][-1])
            pb.show(len(batch_loss)-1, tail_label=tail_label)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        model.eval()
        aux_loss = 0
        N_batches = 0
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            aux_loss += loss.item()
            N_batches += 1
        batch_loss.append(aux_loss/N_batches)

        printout = 'Loss: {:2.2e}'.format(batch_loss[-1])
        if len(loss_history['train']) > 0:
            printout += ' - Delta: {:2.2e}'.format(batch_loss[-1] - loss_history['train'][-1][-1])
        if len(loss_history['train']) > 1:
            d2L_de2 = batch_loss[-1] - 2*loss_history['train'][-1][-1] + loss_history['train'][-2][-1]
            printout +=' - Trend: {:2.2e}'.format(d2L_de2)
        print(printout)

        loss_history['train'].append(batch_loss)

        #### ---- Validation ---- ####
        dataset.charge(dataset.SMMix_val)
        val_data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
        aux_loss = 0
        N_batches = 0
        for local_x, _ in val_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid validation loss!!!')
                raise NameError('LossNAN')
            aux_loss += loss.item()
            N_batches += 1
        loss_history['val'].append(aux_loss/N_batches)
        printout = 'Val Loss: {:2.2e}'.format(loss_history['val'][-1])
        print(printout)
        if epoch > 0:
            if loss_history['val'][-1] < np.min(loss_history['val']):
                print('[INFO]: Saving best model')
                torch.save(model.state_dict(), 'data/model_state_dict_dAE_v'+AEversion+'_best.pkl')

        print('')
        if not earlyStopping.check(loss_history['val'][-1]):
            break

        scheduler.step(batch_loss[-1])

        #### ---- Anomaly Detection monitor ---- ####
        if epoch%3 == 0:
            print('------------ Anomaly Detection monitor ------------')
            BSM_eff['ep'].append(epoch)
            dataset.loss['SMMix'] = np.zeros((0))

            pb = ProgressBar(len(val_data_iter), percentPrecision=5, headLabel='SM Mix: ')
            for i, (local_x, _) in enumerate(val_data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss['SMMix'] = np.concatenate((dataset.loss['SMMix'], loss))

            p_SM = np.logspace(base=10, start=-5, stop=-3, num=3)
            if not 'p_SM' in BSM_eff.keys():
                BSM_eff['p_SM'] = p_SM
            q_SM = np.quantile(dataset.loss['SMMix'], 1-p_SM)

            table = PrettyTable(['SM Mix'] + list(map(lambda x: '{:1.2e}'.format(x), p_SM)))

            for n in dataset.BSM_names:
                dataset.loss[n] = np.zeros((0))

                dataset.charge(dataset.valSamples[n])
                data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
                pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
                for i, (local_x, _) in enumerate(data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss[n] = np.concatenate((dataset.loss[n], loss))

                out = dataset.loss[n] > np.atleast_2d(q_SM).T
                p_BSM = np.float64(np.sum(out, axis=1, dtype=np.float128)/dataset.loss[n].shape[0])
                BSM_eff[n].append(p_BSM)

                table.add_row([n] + list(map(lambda x: '{:1.2e}'.format(x), p_BSM)))
            print(table)                
            print('---------------------------------------------------\n\n')

    model.eval()
    torch.save(model.state_dict(), 'data/model_state_dict_dAE_v'+AEversion+'.pkl');
except NameError:
    if epoch > 0:
        print ('\n\nModel ended up nan. Recovering best model\n')
        model.load_state_dict(torch.load('data/model_state_dict_dAE_v'+AEversion+'_best.pkl'))
    else:
        raise
# Out:
# Epoch 0: [####################]  100% - Tot. time: 16.2 s
# Loss: 1.48e+02
# Val Loss: 1.49e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 6.29e-05 | 1.68e-03 | 2.44e-02 |
# | leptoquark | 2.56e-05 | 6.54e-04 | 1.12e-02 |
# | hToTauTau  | 2.85e-04 | 3.77e-03 | 3.29e-02 |
# | hChToTauNu | 4.85e-04 | 6.11e-03 | 4.56e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 1: [####################]  100% - Tot. time: 16.1 s
# Loss: 1.01e+02 - Delta: -4.78e+01
# Val Loss: 1.01e+02
#
# Epoch 2: [####################]  100% - Tot. time: 16.4 s
# Loss: 9.81e+01 - Delta: -2.67e+00 - Trend: 4.51e+01
# Val Loss: 9.82e+01
#
# Epoch 3: [####################]  100% - Tot. time: 15.9 s
# Loss: 1.40e+02 - Delta: 4.21e+01 - Trend: 4.48e+01
# Val Loss: 1.40e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 17.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 0.00e+00 | 1.26e-04 | 3.27e-03 |
# | leptoquark | 0.00e+00 | 3.65e-05 | 1.41e-03 |
# | hToTauTau  | 4.40e-06 | 8.65e-05 | 2.22e-03 |
# | hChToTauNu | 5.91e-06 | 9.45e-05 | 2.66e-03 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 4: [####################]  100% - Tot. time: 16.0 s
# Loss: 8.01e+01 - Delta: -6.01e+01 - Trend: -1.02e+02
# Val Loss: 8.03e+01
#
# Epoch 5: [####################]  100% - Tot. time: 16.2 s
# Loss: 8.43e+01 - Delta: 4.18e+00 - Trend: 6.42e+01
# Val Loss: 8.44e+01
#
# Epoch 6: [####################]  100% - Tot. time: 16.1 s
# Loss: 7.78e+01 - Delta: -6.51e+00 - Trend: -1.07e+01
# Val Loss: 7.79e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.2 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 0.00e+00 | 2.72e-04 | 1.67e-02 |
# | leptoquark | 2.19e-05 | 3.58e-04 | 8.17e-03 |
# | hToTauTau  | 8.21e-05 | 1.27e-03 | 1.89e-02 |
# | hChToTauNu | 1.51e-04 | 1.99e-03 | 2.68e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 7: [####################]  100% - Tot. time: 16.2 s
# Loss: 1.63e+02 - Delta: 8.47e+01 - Trend: 9.12e+01
# Val Loss: 1.63e+02
#
# Epoch 8: [####################]  100% - Tot. time: 16.1 s
# Loss: 7.74e+01 - Delta: -8.51e+01 - Trend: -1.70e+02
# Val Loss: 7.76e+01
#
# Epoch 9: [####################]  100% - Tot. time: 16.2 s
# Loss: 7.61e+01 - Delta: -1.31e+00 - Trend: 8.38e+01
# Val Loss: 7.63e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 1.73e-02 |
# | leptoquark | 4.02e-05 | 6.10e-04 | 1.03e-02 |
# | hToTauTau  | 8.95e-05 | 1.21e-03 | 2.20e-02 |
# | hChToTauNu | 9.75e-05 | 1.58e-03 | 3.04e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 10: [####################]  100% - Tot. time: 16.4 s
# Loss: 7.48e+01 - Delta: -1.35e+00 - Trend: -4.00e-02
# Val Loss: 7.49e+01
#
# Epoch 11: [####################]  100% - Tot. time: 17.4 s
# Loss: 7.39e+01 - Delta: -8.63e-01 - Trend: 4.91e-01
# Val Loss: 7.41e+01
#
# Epoch 12: [####################]  100% - Tot. time: 16.5 s
# Loss: 7.22e+01 - Delta: -1.71e+00 - Trend: -8.44e-01
# Val Loss: 7.24e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 2.43e-03 | 2.05e-02 |
# | leptoquark | 9.87e-05 | 8.22e-04 | 9.21e-03 |
# | hToTauTau  | 2.08e-04 | 1.43e-03 | 1.75e-02 |
# | hChToTauNu | 3.28e-04 | 2.17e-03 | 2.44e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 13: [####################]  100% - Tot. time: 16.3 s
# Loss: 7.41e+01 - Delta: 1.91e+00 - Trend: 3.62e+00
# Val Loss: 7.43e+01
#
# Epoch 14: [####################]  100% - Tot. time: 16.8 s
# Loss: 8.22e+01 - Delta: 8.05e+00 - Trend: 6.14e+00
# Val Loss: 8.23e+01
#
# Epoch 15: [####################]  100% - Tot. time: 16.2 s
# Loss: 7.24e+01 - Delta: -9.72e+00 - Trend: -1.78e+01
# Val Loss: 7.26e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.68e-04 | 1.66e-03 | 2.45e-02 |
# | leptoquark | 1.46e-04 | 1.47e-03 | 1.66e-02 |
# | hToTauTau  | 4.80e-04 | 4.33e-03 | 3.73e-02 |
# | hChToTauNu | 6.38e-04 | 6.53e-03 | 5.09e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 16: [####################]  100% - Tot. time: 16.1 s
# Loss: 6.86e+01 - Delta: -3.88e+00 - Trend: 5.85e+00
# Val Loss: 6.87e+01
#
# Epoch 17: [####################]  100% - Tot. time: 16.6 s
# Loss: 7.13e+01 - Delta: 2.79e+00 - Trend: 6.67e+00
# Val Loss: 7.15e+01
#
# Epoch 18: [####################]  100% - Tot. time: 16.3 s
# Loss: 8.32e+01 - Delta: 1.19e+01 - Trend: 9.12e+00
# Val Loss: 8.34e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.1 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.05e-04 | 1.13e-03 | 2.78e-02 |
# | leptoquark | 7.31e-05 | 1.35e-03 | 2.12e-02 |
# | hToTauTau  | 5.35e-04 | 6.32e-03 | 5.10e-02 |
# | hChToTauNu | 9.72e-04 | 1.06e-02 | 6.85e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 19: [####################]  100% - Tot. time: 16.5 s
# Loss: 6.33e+01 - Delta: -2.00e+01 - Trend: -3.19e+01
# Val Loss: 6.34e+01
#
# Epoch 20: [####################]  100% - Tot. time: 16.3 s
# Loss: 6.17e+01 - Delta: -1.52e+00 - Trend: 1.85e+01
# Val Loss: 6.19e+01
#
# Epoch 21: [####################]  100% - Tot. time: 16.3 s
# Loss: 6.91e+01 - Delta: 7.35e+00 - Trend: 8.88e+00
# Val Loss: 6.92e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.68e-04 | 2.96e-03 | 3.81e-02 |
# | leptoquark | 6.21e-05 | 1.55e-03 | 1.92e-02 |
# | hToTauTau  | 3.61e-04 | 5.62e-03 | 4.16e-02 |
# | hChToTauNu | 5.94e-04 | 9.04e-03 | 5.64e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 22: [####################]  100% - Tot. time: 16.2 s
# Loss: 7.47e+01 - Delta: 5.63e+00 - Trend: -1.73e+00
# Val Loss: 7.49e+01
#
# Epoch 23: [####################]  100% - Tot. time: 16.5 s
# Loss: 5.93e+01 - Delta: -1.54e+01 - Trend: -2.11e+01
# Val Loss: 5.94e+01
#
# Epoch 24: [####################]  100% - Tot. time: 16.6 s
# Loss: 6.29e+01 - Delta: 3.65e+00 - Trend: 1.91e+01
# Val Loss: 6.31e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 7.97e-04 | 9.22e-03 | 5.17e-02 |
# | leptoquark | 2.89e-04 | 2.16e-03 | 1.76e-02 |
# | hToTauTau  | 4.78e-04 | 4.57e-03 | 3.59e-02 |
# | hChToTauNu | 7.89e-04 | 6.94e-03 | 4.93e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 25: [####################]  100% - Tot. time: 16.2 s
# Loss: 8.33e+01 - Delta: 2.04e+01 - Trend: 1.67e+01
# Val Loss: 8.34e+01
#
# Epoch 26: [####################]  100% - Tot. time: 16.3 s
# Loss: 5.75e+01 - Delta: -2.58e+01 - Trend: -4.61e+01
# Val Loss: 5.77e+01
#
# Epoch 27: [####################]  100% - Tot. time: 16.2 s
# Loss: 5.72e+01 - Delta: -3.04e-01 - Trend: 2.55e+01
# Val Loss: 5.74e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 9.22e-04 | 9.85e-03 | 4.42e-02 |
# | leptoquark | 3.18e-04 | 2.09e-03 | 1.45e-02 |
# | hToTauTau  | 4.59e-04 | 3.67e-03 | 2.87e-02 |
# | hChToTauNu | 7.33e-04 | 5.55e-03 | 3.97e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 28: [####################]  100% - Tot. time: 16.0 s
# Loss: 6.81e+01 - Delta: 1.08e+01 - Trend: 1.11e+01
# Val Loss: 6.82e+01
#
# Epoch 29: [####################]  100% - Tot. time: 16.3 s
# Loss: 6.69e+01 - Delta: -1.19e+00 - Trend: -1.20e+01
# Val Loss: 6.70e+01
#
# Epoch 30: [####################]  100% - Tot. time: 16.3 s
# Loss: 6.21e+01 - Delta: -4.83e+00 - Trend: -3.64e+00
# Val Loss: 6.22e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 8.80e-04 | 9.33e-03 | 4.86e-02 |
# | leptoquark | 3.33e-04 | 2.59e-03 | 2.09e-02 |
# | hToTauTau  | 5.46e-04 | 6.07e-03 | 4.35e-02 |
# | hChToTauNu | 8.42e-04 | 9.26e-03 | 5.88e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 31: [####################]  100% - Tot. time: 16.2 s
# Loss: 7.48e+01 - Delta: 1.27e+01 - Trend: 1.76e+01
# Val Loss: 7.49e+01
#
# Epoch    31: reducing learning rate of group 0 to 3.0000e-04.
# Epoch 32: [####################]  100% - Tot. time: 16.5 s
# Loss: 5.31e+01 - Delta: -2.16e+01 - Trend: -3.44e+01
# Val Loss: 5.33e+01
#
# Epoch 33: [####################]  100% - Tot. time: 16.2 s
# Loss: 5.26e+01 - Delta: -5.92e-01 - Trend: 2.11e+01
# Val Loss: 5.27e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 7.55e-04 | 5.18e-03 | 3.07e-02 |
# | leptoquark | 1.17e-04 | 1.45e-03 | 1.45e-02 |
# | hToTauTau  | 4.80e-04 | 4.19e-03 | 3.20e-02 |
# | hChToTauNu | 7.59e-04 | 6.59e-03 | 4.42e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 34: [####################]  100% - Tot. time: 16.2 s
# Loss: 5.22e+01 - Delta: -4.00e-01 - Trend: 1.92e-01
# Val Loss: 5.23e+01
#
# Epoch 35: [####################]  100% - Tot. time: 16.4 s
# Loss: 5.15e+01 - Delta: -6.29e-01 - Trend: -2.29e-01
# Val Loss: 5.17e+01
#
# Epoch 36: [####################]  100% - Tot. time: 16.2 s
# Loss: 4.99e+01 - Delta: -1.61e+00 - Trend: -9.79e-01
# Val Loss: 5.01e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.4 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.43e-03 | 8.53e-03 | 3.74e-02 |
# | leptoquark | 1.10e-04 | 1.59e-03 | 1.65e-02 |
# | hToTauTau  | 4.72e-04 | 4.75e-03 | 3.72e-02 |
# | hChToTauNu | 7.18e-04 | 7.27e-03 | 5.06e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 37: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.88e+01 - Delta: -1.14e+00 - Trend: 4.69e-01
# Val Loss: 4.89e+01
#
# Epoch 38: [####################]  100% - Tot. time: 16.6 s
# Loss: 5.27e+01 - Delta: 3.94e+00 - Trend: 5.08e+00
# Val Loss: 5.29e+01
#
# Epoch 39: [####################]  100% - Tot. time: 16.3 s
# Loss: 5.05e+01 - Delta: -2.20e+00 - Trend: -6.14e+00
# Val Loss: 5.07e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.62e-03 | 1.21e-02 | 4.27e-02 |
# | leptoquark | 1.72e-04 | 1.82e-03 | 1.71e-02 |
# | hToTauTau  | 5.93e-04 | 5.17e-03 | 3.79e-02 |
# | hChToTauNu | 8.48e-04 | 7.82e-03 | 5.16e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 40: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.78e+01 - Delta: -2.74e+00 - Trend: -5.48e-01
# Val Loss: 4.79e+01
#
# Epoch 41: [####################]  100% - Tot. time: 16.0 s
# Loss: 4.83e+01 - Delta: 5.64e-01 - Trend: 3.31e+00
# Val Loss: 4.85e+01
#
# Epoch 42: [####################]  100% - Tot. time: 16.6 s
# Loss: 4.69e+01 - Delta: -1.48e+00 - Trend: -2.04e+00
# Val Loss: 4.70e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.31e-03 | 1.50e-02 | 4.98e-02 |
# | leptoquark | 1.75e-04 | 1.97e-03 | 1.88e-02 |
# | hToTauTau  | 5.68e-04 | 5.36e-03 | 4.10e-02 |
# | hChToTauNu | 8.69e-04 | 8.11e-03 | 5.58e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 43: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.62e+01 - Delta: -7.11e-01 - Trend: 7.69e-01
# Val Loss: 4.63e+01
#
# Epoch 44: [####################]  100% - Tot. time: 16.7 s
# Loss: 4.70e+01 - Delta: 8.91e-01 - Trend: 1.60e+00
# Val Loss: 4.72e+01
#
# Epoch 45: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.47e+01 - Delta: -2.34e+00 - Trend: -3.24e+00
# Val Loss: 4.49e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.02e-03 | 1.42e-02 | 5.20e-02 |
# | leptoquark | 1.13e-04 | 1.96e-03 | 1.94e-02 |
# | hToTauTau  | 4.49e-04 | 5.23e-03 | 4.17e-02 |
# | hChToTauNu | 6.77e-04 | 7.90e-03 | 5.71e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 46: [####################]  100% - Tot. time: 16.9 s
# Loss: 4.45e+01 - Delta: -2.30e-01 - Trend: 2.12e+00
# Val Loss: 4.46e+01
#
# Epoch 47: [####################]  100% - Tot. time: 16.5 s
# Loss: 4.39e+01 - Delta: -5.94e-01 - Trend: -3.64e-01
# Val Loss: 4.40e+01
#
# Epoch 48: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.48e+01 - Delta: 9.45e-01 - Trend: 1.54e+00
# Val Loss: 4.50e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.19e-03 | 1.73e-02 | 6.18e-02 |
# | leptoquark | 1.90e-04 | 2.24e-03 | 2.00e-02 |
# | hToTauTau  | 5.65e-04 | 5.29e-03 | 4.00e-02 |
# | hChToTauNu | 8.42e-04 | 7.86e-03 | 5.47e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 49: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.30e+01 - Delta: -1.78e+00 - Trend: -2.72e+00
# Val Loss: 4.32e+01
#
# Epoch 50: [####################]  100% - Tot. time: 16.5 s
# Loss: 4.32e+01 - Delta: 1.58e-01 - Trend: 1.93e+00
# Val Loss: 4.34e+01
#
# Epoch 51: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.36e+01 - Delta: 4.46e-01 - Trend: 2.87e-01
# Val Loss: 4.38e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.89e-03 | 1.36e-02 | 5.76e-02 |
# | leptoquark | 9.14e-05 | 1.94e-03 | 2.01e-02 |
# | hToTauTau  | 3.84e-04 | 4.92e-03 | 4.07e-02 |
# | hChToTauNu | 5.67e-04 | 7.64e-03 | 5.58e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 52: [####################]  100% - Tot. time: 16.2 s
# Loss: 4.34e+01 - Delta: -2.66e-01 - Trend: -7.12e-01
# Val Loss: 4.35e+01
#
# Epoch 53: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.24e+01 - Delta: -1.02e+00 - Trend: -7.49e-01
# Val Loss: 4.25e+01
#
# Epoch 54: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.24e+01 - Delta: 5.54e-02 - Trend: 1.07e+00
# Val Loss: 4.26e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.2 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.3 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.72e-03 | 1.21e-02 | 5.39e-02 |
# | leptoquark | 1.28e-04 | 1.96e-03 | 1.96e-02 |
# | hToTauTau  | 3.95e-04 | 4.89e-03 | 4.05e-02 |
# | hChToTauNu | 5.17e-04 | 7.67e-03 | 5.58e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 55: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.21e+01 - Delta: -3.18e-01 - Trend: -3.73e-01
# Val Loss: 4.23e+01
#
# Epoch 56: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.24e+01 - Delta: 3.23e-01 - Trend: 6.41e-01
# Val Loss: 4.26e+01
#
# Epoch 57: [####################]  100% - Tot. time: 16.2 s
# Loss: 4.26e+01 - Delta: 1.82e-01 - Trend: -1.41e-01
# Val Loss: 4.28e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.19e-03 | 1.05e-02 | 5.39e-02 |
# | leptoquark | 9.50e-05 | 1.83e-03 | 1.91e-02 |
# | hToTauTau  | 3.75e-04 | 4.64e-03 | 3.98e-02 |
# | hChToTauNu | 5.38e-04 | 7.23e-03 | 5.43e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 58: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.23e+01 - Delta: -3.55e-01 - Trend: -5.37e-01
# Val Loss: 4.24e+01
#
# Epoch 59: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.17e+01 - Delta: -5.59e-01 - Trend: -2.04e-01
# Val Loss: 4.19e+01
#
# Epoch 60: [####################]  100% - Tot. time: 16.3 s
# Loss: 5.51e+01 - Delta: 1.34e+01 - Trend: 1.39e+01
# Val Loss: 5.52e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.2 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.32e-03 | 1.08e-02 | 5.61e-02 |
# | leptoquark | 1.43e-04 | 1.71e-03 | 1.82e-02 |
# | hToTauTau  | 3.24e-04 | 3.93e-03 | 3.69e-02 |
# | hChToTauNu | 4.55e-04 | 6.22e-03 | 5.07e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 61: [####################]  100% - Tot. time: 16.6 s
# Loss: 4.44e+01 - Delta: -1.07e+01 - Trend: -2.40e+01
# Val Loss: 4.45e+01
#
# Epoch 62: [####################]  100% - Tot. time: 16.3 s
# Loss: 4.17e+01 - Delta: -2.72e+00 - Trend: 7.95e+00
# Val Loss: 4.18e+01
#
# Epoch 63: [####################]  100% - Tot. time: 16.6 s
# Loss: 4.14e+01 - Delta: -2.97e-01 - Trend: 2.43e+00
# Val Loss: 4.15e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 9.64e-04 | 1.00e-02 | 5.09e-02 |
# | leptoquark | 1.43e-04 | 1.72e-03 | 1.88e-02 |
# | hToTauTau  | 3.39e-04 | 4.37e-03 | 3.91e-02 |
# | hChToTauNu | 4.73e-04 | 6.86e-03 | 5.31e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 64: [####################]  100% - Tot. time: 16.5 s
# Loss: 4.05e+01 - Delta: -8.49e-01 - Trend: -5.52e-01
# Val Loss: 4.22e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.6 s
# hToTauTau: [##############]  100% - Tot. time: 2.8 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 9.64e-04 | 1.00e-02 | 5.04e-02 |
# | leptoquark | 1.57e-04 | 1.74e-03 | 1.90e-02 |
# | hToTauTau  | 3.18e-04 | 4.16e-03 | 3.95e-02 |
# | hChToTauNu | 4.37e-04 | 6.57e-03 | 5.38e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 67: [####################]  100% - Tot. time: 16.0 s
# Loss: 4.45e+01 - Delta: 2.46e+00 - Trend: 2.35e+00
# Val Loss: 4.47e+01
#
# Epoch 68: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.02e+01 - Delta: -4.32e+00 - Trend: -6.78e+00
# Val Loss: 4.04e+01
#
# Epoch 69: [####################]  100% - Tot. time: 16.6 s
# Loss: 4.02e+01 - Delta: -2.43e-02 - Trend: 4.29e+00
# Val Loss: 4.04e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.22e-03 | 1.04e-02 | 5.07e-02 |
# | leptoquark | 1.57e-04 | 1.92e-03 | 1.95e-02 |
# | hToTauTau  | 2.98e-04 | 4.46e-03 | 4.04e-02 |
# | hChToTauNu | 4.37e-04 | 7.02e-03 | 5.47e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 70: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.06e+01 - Delta: 3.62e-01 - Trend: 3.87e-01
# Val Loss: 4.07e+01
#
# Epoch 71: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.78e+01 - Delta: 7.24e+00 - Trend: 6.88e+00
# Val Loss: 4.80e+01
#
# Epoch 72: [####################]  100% - Tot. time: 15.8 s
# Loss: 4.13e+01 - Delta: -6.51e+00 - Trend: -1.37e+01
# Val Loss: 4.15e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.28e-03 | 1.12e-02 | 5.21e-02 |
# | leptoquark | 1.94e-04 | 1.96e-03 | 1.94e-02 |
# | hToTauTau  | 3.20e-04 | 4.10e-03 | 3.94e-02 |
# | hChToTauNu | 4.70e-04 | 6.45e-03 | 5.33e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 73: [####################]  100% - Tot. time: 16.1 s
# Loss: 4.07e+01 - Delta: -6.37e-01 - Trend: 5.87e+00
# Val Loss: 4.08e+01
#
# Epoch    73: reducing learning rate of group 0 to 9.0000e-05.
# Epoch 74: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.93e+01 - Delta: -1.33e+00 - Trend: -6.94e-01
# Val Loss: 3.95e+01
#
# Epoch 75: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.87e+01 - Delta: -6.71e-01 - Trend: 6.59e-01
# Val Loss: 3.88e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.32e-03 | 1.13e-02 | 5.02e-02 |
# | leptoquark | 2.01e-04 | 2.04e-03 | 1.89e-02 |
# | hToTauTau  | 3.01e-04 | 4.25e-03 | 3.95e-02 |
# | hChToTauNu | 4.31e-04 | 6.69e-03 | 5.34e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 76: [####################]  100% - Tot. time: 16.0 s
# Loss: 3.82e+01 - Delta: -4.47e-01 - Trend: 2.25e-01
# Val Loss: 3.84e+01
#
# Epoch 77: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.86e+01 - Delta: 3.95e-01 - Trend: 8.42e-01
# Val Loss: 3.88e+01
#
# Epoch 78: [####################]  100% - Tot. time: 15.8 s
# Loss: 3.78e+01 - Delta: -8.38e-01 - Trend: -1.23e+00
# Val Loss: 3.79e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.15e-03 | 1.12e-02 | 5.01e-02 |
# | leptoquark | 2.05e-04 | 2.02e-03 | 1.90e-02 |
# | hToTauTau  | 2.71e-04 | 4.27e-03 | 3.99e-02 |
# | hChToTauNu | 3.81e-04 | 6.62e-03 | 5.39e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 79: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.77e+01 - Delta: -6.60e-02 - Trend: 7.72e-01
# Val Loss: 3.79e+01
#
# Epoch 80: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.75e+01 - Delta: -2.18e-01 - Trend: -1.52e-01
# Val Loss: 3.77e+01
#
# Epoch 81: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.75e+01 - Delta: 5.47e-03 - Trend: 2.23e-01
# Val Loss: 3.77e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.28e-03 | 1.12e-02 | 5.01e-02 |
# | leptoquark | 1.90e-04 | 1.99e-03 | 1.94e-02 |
# | hToTauTau  | 2.93e-04 | 4.44e-03 | 4.08e-02 |
# | hChToTauNu | 4.25e-04 | 6.97e-03 | 5.53e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 82: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.73e+01 - Delta: -1.54e-01 - Trend: -1.60e-01
# Val Loss: 3.75e+01
#
# Epoch 83: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.73e+01 - Delta: -3.83e-02 - Trend: 1.16e-01
# Val Loss: 3.75e+01
#
# Epoch 84: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.73e+01 - Delta: -3.32e-02 - Trend: 5.10e-03
# Val Loss: 3.74e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.36e-03 | 1.16e-02 | 5.23e-02 |
# | leptoquark | 2.49e-04 | 2.12e-03 | 1.99e-02 |
# | hToTauTau  | 3.33e-04 | 4.27e-03 | 4.08e-02 |
# | hChToTauNu | 4.64e-04 | 6.72e-03 | 5.55e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 85: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.70e+01 - Delta: -3.04e-01 - Trend: -2.71e-01
# Val Loss: 3.71e+01
#
# Epoch 86: [####################]  100% - Tot. time: 16.6 s
# Loss: 3.70e+01 - Delta: -8.11e-03 - Trend: 2.96e-01
# Val Loss: 3.71e+01
#
# Epoch 87: [####################]  100% - Tot. time: 16.4 s
# Loss: 4.77e+01 - Delta: 1.07e+01 - Trend: 1.07e+01
# Val Loss: 4.79e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.70e-03 | 1.19e-02 | 5.27e-02 |
# | leptoquark | 2.81e-04 | 2.10e-03 | 1.84e-02 |
# | hToTauTau  | 3.43e-04 | 3.80e-03 | 3.73e-02 |
# | hChToTauNu | 4.90e-04 | 5.89e-03 | 5.09e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 88: [####################]  100% - Tot. time: 16.3 s
# Loss: 6.03e+01 - Delta: 1.26e+01 - Trend: 1.90e+00
# Val Loss: 6.05e+01
#
# Epoch 89: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.74e+01 - Delta: -2.29e+01 - Trend: -3.55e+01
# Val Loss: 3.76e+01
#
# Epoch 90: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.66e+01 - Delta: -8.74e-01 - Trend: 2.20e+01
# Val Loss: 3.67e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.43e-03 | 1.14e-02 | 4.99e-02 |
# | leptoquark | 2.59e-04 | 2.22e-03 | 1.98e-02 |
# | hToTauTau  | 3.55e-04 | 4.73e-03 | 4.15e-02 |
# | hChToTauNu | 5.11e-04 | 7.33e-03 | 5.64e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 91: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.64e+01 - Delta: -1.51e-01 - Trend: 7.23e-01
# Val Loss: 3.66e+01
#
# Epoch 92: [####################]  100% - Tot. time: 16.2 s
# Loss: 4.38e+01 - Delta: 7.39e+00 - Trend: 7.54e+00
# Val Loss: 4.39e+01
#
# Epoch 93: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.62e+01 - Delta: -7.56e+00 - Trend: -1.49e+01
# Val Loss: 3.64e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 2.9 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.47e-03 | 1.15e-02 | 5.01e-02 |
# | leptoquark | 2.74e-04 | 2.29e-03 | 2.04e-02 |
# | hToTauTau  | 3.86e-04 | 4.88e-03 | 4.27e-02 |
# | hChToTauNu | 5.52e-04 | 7.56e-03 | 5.79e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 94: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.61e+01 - Delta: -9.91e-02 - Trend: 7.46e+00
# Val Loss: 3.63e+01
#
# Epoch 95: [####################]  100% - Tot. time: 16.5 s
# Loss: 3.61e+01 - Delta: -7.03e-02 - Trend: 2.88e-02
# Val Loss: 3.62e+01
#
# Epoch 96: [####################]  100% - Tot. time: 16.5 s
# Loss: 3.67e+01 - Delta: 6.29e-01 - Trend: 6.99e-01
# Val Loss: 3.69e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.53e-03 | 1.18e-02 | 5.05e-02 |
# | leptoquark | 2.67e-04 | 2.32e-03 | 2.03e-02 |
# | hToTauTau  | 3.83e-04 | 4.95e-03 | 4.28e-02 |
# | hChToTauNu | 5.85e-04 | 7.72e-03 | 5.81e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 97: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.60e+01 - Delta: -7.31e-01 - Trend: -1.36e+00
# Val Loss: 3.61e+01
#
# Epoch 98: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.59e+01 - Delta: -3.37e-02 - Trend: 6.97e-01
# Val Loss: 3.61e+01
#
# Epoch 99: [####################]  100% - Tot. time: 16.5 s
# Loss: 3.58e+01 - Delta: -1.37e-01 - Trend: -1.03e-01
# Val Loss: 3.60e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.8 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.40e-03 | 1.15e-02 | 4.93e-02 |
# | leptoquark | 2.45e-04 | 2.28e-03 | 2.05e-02 |
# | hToTauTau  | 3.96e-04 | 5.16e-03 | 4.31e-02 |
# | hChToTauNu | 5.79e-04 | 7.94e-03 | 5.85e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 100: [####################]  100% - Tot. time: 16.5 s
# Loss: 3.60e+01 - Delta: 1.63e-01 - Trend: 3.00e-01
# Val Loss: 3.61e+01
#
# Epoch 101: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.56e+01 - Delta: -3.50e-01 - Trend: -5.13e-01
# Val Loss: 3.58e+01
#
# Epoch 102: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.56e+01 - Delta: -2.22e-02 - Trend: 3.28e-01
# Val Loss: 3.58e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.40e-03 | 1.14e-02 | 4.95e-02 |
# | leptoquark | 2.49e-04 | 2.26e-03 | 2.09e-02 |
# | hToTauTau  | 3.96e-04 | 5.12e-03 | 4.40e-02 |
# | hChToTauNu | 5.76e-04 | 7.89e-03 | 5.96e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 103: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.56e+01 - Delta: 2.43e-03 - Trend: 2.46e-02
# Val Loss: 3.58e+01
#
# Epoch 104: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.55e+01 - Delta: -9.04e-02 - Trend: -9.29e-02
# Val Loss: 3.57e+01
#
# Epoch 105: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.59e+01 - Delta: 4.14e-01 - Trend: 5.05e-01
# Val Loss: 3.61e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 20.0 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.45e-03 | 1.20e-02 | 5.19e-02 |
# | leptoquark | 2.70e-04 | 2.38e-03 | 2.13e-02 |
# | hToTauTau  | 3.74e-04 | 5.09e-03 | 4.42e-02 |
# | hChToTauNu | 5.50e-04 | 7.89e-03 | 6.00e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 106: [####################]  100% - Tot. time: 16.4 s
# Loss: 3.65e+01 - Delta: 6.19e-01 - Trend: 2.05e-01
# Val Loss: 3.67e+01
#
# Epoch 107: [####################]  100% - Tot. time: 15.9 s
# Loss: 3.54e+01 - Delta: -1.18e+00 - Trend: -1.80e+00
# Val Loss: 3.55e+01
#
# Epoch 108: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.53e+01 - Delta: -9.78e-02 - Trend: 1.08e+00
# Val Loss: 3.54e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.40e-03 | 1.15e-02 | 4.85e-02 |
# | leptoquark | 2.27e-04 | 2.36e-03 | 2.08e-02 |
# | hToTauTau  | 3.87e-04 | 5.38e-03 | 4.40e-02 |
# | hChToTauNu | 5.94e-04 | 8.20e-03 | 5.98e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 109: [####################]  100% - Tot. time: 16.5 s
# Loss: 3.52e+01 - Delta: -4.07e-02 - Trend: 5.70e-02
# Val Loss: 3.54e+01
#
# Epoch 110: [####################]  100% - Tot. time: 17.3 s
# Loss: 3.59e+01 - Delta: 7.10e-01 - Trend: 7.51e-01
# Val Loss: 3.61e+01
#
# Epoch 111: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.52e+01 - Delta: -6.94e-01 - Trend: -1.40e+00
# Val Loss: 3.54e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.0 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.45e-03 | 1.20e-02 | 4.94e-02 |
# | leptoquark | 2.41e-04 | 2.46e-03 | 2.12e-02 |
# | hToTauTau  | 3.96e-04 | 5.54e-03 | 4.48e-02 |
# | hChToTauNu | 6.00e-04 | 8.47e-03 | 6.08e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 112: [####################]  100% - Tot. time: 15.8 s
# Loss: 3.54e+01 - Delta: 1.66e-01 - Trend: 8.60e-01
# Val Loss: 3.56e+01
#
# Epoch 113: [####################]  100% - Tot. time: 16.1 s
# Loss: 3.51e+01 - Delta: -3.06e-01 - Trend: -4.72e-01
# Val Loss: 3.53e+01
#
# Epoch 114: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.49e+01 - Delta: -1.86e-01 - Trend: 1.20e-01
# Val Loss: 3.51e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.2 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.47e-03 | 1.18e-02 | 4.91e-02 |
# | leptoquark | 2.30e-04 | 2.40e-03 | 2.11e-02 |
# | hToTauTau  | 4.30e-04 | 5.39e-03 | 4.47e-02 |
# | hChToTauNu | 6.23e-04 | 8.20e-03 | 6.07e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 115: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.48e+01 - Delta: -1.02e-01 - Trend: 8.42e-02
# Val Loss: 3.50e+01
#
# Epoch 116: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.50e+01 - Delta: 1.58e-01 - Trend: 2.60e-01
# Val Loss: 3.51e+01
#
# Epoch 117: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.76e+01 - Delta: 2.61e+00 - Trend: 2.45e+00
# Val Loss: 3.77e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 1.57e-03 | 1.17e-02 | 4.86e-02 |
# | leptoquark | 2.34e-04 | 2.34e-03 | 2.06e-02 |
# | hToTauTau  | 4.46e-04 | 5.34e-03 | 4.38e-02 |
# | hChToTauNu | 6.62e-04 | 8.12e-03 | 5.95e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 118: [####################]  100% - Tot. time: 16.3 s
# Loss: 3.48e+01 - Delta: -2.79e+00 - Trend: -5.40e+00
# Val Loss: 3.50e+01
#
# Epoch 119: [####################]  100% - Tot. time: 16.2 s
# Loss: 3.49e+01 - Delta: 1.39e-01 - Trend: 2.93e+00
# Val Loss: 3.51e+01
#
# Epoch 120: [####################]  100% - Tot. time: 15.9 s
# Loss: 3.45e+01 - Delta: -4.34e-01 - Trend: -5.72e-01
# Val Loss: 3.47e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.4 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# ...
# Val Loss: 2.57e+01
#
# Epoch 395: [####################]  100% - Tot. time: 16.2 s
# Loss: 2.55e+01 - Delta: -1.95e-03 - Trend: 2.03e-03
# Val Loss: 2.57e+01
#
# Epoch 396: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.55e+01 - Delta: -5.97e-03 - Trend: -4.02e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.9 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.93e-04 | 3.48e-03 | 4.33e-02 |
# | leptoquark | 2.92e-05 | 7.57e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.15e-03 | 3.00e-02 |
# | hChToTauNu | 1.33e-04 | 1.39e-03 | 4.16e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 397: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.55e+01 - Delta: 3.91e-03 - Trend: 9.89e-03
# Val Loss: 2.57e+01
#
# Epoch 398: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.55e+01 - Delta: -4.93e-03 - Trend: -8.85e-03
# Val Loss: 2.57e+01
#
# Epoch 399: [####################]  100% - Tot. time: 16.6 s
# Loss: 2.55e+01 - Delta: 2.32e-03 - Trend: 7.26e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.8 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 2.9 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.93e-04 | 3.48e-03 | 4.33e-02 |
# | leptoquark | 2.92e-05 | 7.60e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.16e-03 | 2.99e-02 |
# | hChToTauNu | 1.33e-04 | 1.40e-03 | 4.16e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 400: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.55e+01 - Delta: -1.61e-02 - Trend: -1.84e-02
# Val Loss: 2.57e+01
#
# Epoch 401: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.55e+01 - Delta: 2.64e-05 - Trend: 1.61e-02
# Val Loss: 2.57e+01
#
# Epoch 402: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.55e+01 - Delta: -3.87e-03 - Trend: -3.90e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.93e-04 | 3.48e-03 | 4.34e-02 |
# | leptoquark | 2.92e-05 | 7.60e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.15e-03 | 3.00e-02 |
# | hChToTauNu | 1.33e-04 | 1.39e-03 | 4.16e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 403: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.55e+01 - Delta: -6.91e-03 - Trend: -3.04e-03
# Val Loss: 2.57e+01
#
# Epoch 404: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.55e+01 - Delta: 2.73e-03 - Trend: 9.64e-03
# Val Loss: 2.57e+01
#
# Epoch 405: [####################]  100% - Tot. time: 17.9 s
# Loss: 2.55e+01 - Delta: -6.63e-03 - Trend: -9.36e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.93e-04 | 3.48e-03 | 4.33e-02 |
# | leptoquark | 2.92e-05 | 7.64e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.16e-03 | 2.99e-02 |
# | hChToTauNu | 1.33e-04 | 1.42e-03 | 4.15e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 406: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.55e+01 - Delta: -7.05e-03 - Trend: -4.28e-04
# Val Loss: 2.57e+01
#
# Epoch 407: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.54e+01 - Delta: -3.76e-03 - Trend: 3.30e-03
# Val Loss: 2.57e+01
#
# Epoch 408: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: 2.35e-03 - Trend: 6.11e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 2.93e-04 | 3.48e-03 | 4.33e-02 |
# | leptoquark | 2.92e-05 | 7.60e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.15e-03 | 2.99e-02 |
# | hChToTauNu | 1.33e-04 | 1.41e-03 | 4.15e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 409: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: -7.95e-03 - Trend: -1.03e-02
# Val Loss: 2.57e+01
#
# Epoch 410: [####################]  100% - Tot. time: 16.7 s
# Loss: 2.54e+01 - Delta: -7.43e-04 - Trend: 7.21e-03
# Val Loss: 2.57e+01
#
# Epoch 411: [####################]  100% - Tot. time: 17.2 s
# Loss: 2.54e+01 - Delta: -7.15e-03 - Trend: -6.41e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.48e-03 | 4.33e-02 |
# | leptoquark | 2.92e-05 | 7.57e-04 | 1.49e-02 |
# | hToTauTau  | 9.39e-05 | 1.15e-03 | 2.99e-02 |
# | hChToTauNu | 1.33e-04 | 1.41e-03 | 4.15e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 412: [####################]  100% - Tot. time: 16.8 s
# Loss: 2.54e+01 - Delta: 4.95e-03 - Trend: 1.21e-02
# Val Loss: 2.57e+01
#
# Epoch 413: [####################]  100% - Tot. time: 16.7 s
# Loss: 2.54e+01 - Delta: -4.13e-03 - Trend: -9.08e-03
# Val Loss: 2.57e+01
#
# Epoch 414: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.54e+01 - Delta: -1.00e-02 - Trend: -5.92e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.2 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.44e-03 | 4.32e-02 |
# | leptoquark | 2.92e-05 | 7.57e-04 | 1.48e-02 |
# | hToTauTau  | 9.39e-05 | 1.14e-03 | 2.98e-02 |
# | hChToTauNu | 1.33e-04 | 1.40e-03 | 4.14e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 415: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: -5.65e-03 - Trend: 4.39e-03
# Val Loss: 2.57e+01
#
# Epoch 416: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.54e+01 - Delta: 7.16e-03 - Trend: 1.28e-02
# Val Loss: 2.57e+01
#
# Epoch 417: [####################]  100% - Tot. time: 16.6 s
# Loss: 2.54e+01 - Delta: -1.28e-02 - Trend: -2.00e-02
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.7 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.8 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.44e-03 | 4.31e-02 |
# | leptoquark | 2.92e-05 | 7.57e-04 | 1.48e-02 |
# | hToTauTau  | 9.39e-05 | 1.15e-03 | 2.98e-02 |
# | hChToTauNu | 1.33e-04 | 1.40e-03 | 4.13e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 418: [####################]  100% - Tot. time: 16.6 s
# Loss: 2.54e+01 - Delta: -2.55e-03 - Trend: 1.03e-02
# Val Loss: 2.57e+01
#
# Epoch 419: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: -2.57e-04 - Trend: 2.30e-03
# Val Loss: 2.57e+01
#
# Epoch 420: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: -7.10e-03 - Trend: -6.84e-03
# Val Loss: 2.57e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.6 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.0 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.44e-03 | 4.32e-02 |
# | leptoquark | 2.92e-05 | 7.53e-04 | 1.48e-02 |
# | hToTauTau  | 9.53e-05 | 1.13e-03 | 2.98e-02 |
# | hChToTauNu | 1.33e-04 | 1.39e-03 | 4.13e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 421: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.54e+01 - Delta: -1.89e-03 - Trend: 5.21e-03
# Val Loss: 2.57e+01
#
# Epoch 422: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.54e+01 - Delta: -4.14e-03 - Trend: -2.25e-03
# Val Loss: 2.57e+01
#
# Epoch 423: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: -5.63e-03 - Trend: -1.49e-03
# Val Loss: 2.56e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.3 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.44e-03 | 4.32e-02 |
# | leptoquark | 2.92e-05 | 7.46e-04 | 1.48e-02 |
# | hToTauTau  | 9.53e-05 | 1.13e-03 | 2.98e-02 |
# | hChToTauNu | 1.33e-04 | 1.39e-03 | 4.13e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 424: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.54e+01 - Delta: -2.57e-03 - Trend: 3.06e-03
# Val Loss: 2.56e+01
#
# Epoch 425: [####################]  100% - Tot. time: 17.1 s
# Loss: 2.54e+01 - Delta: 1.91e-03 - Trend: 4.48e-03
# Val Loss: 2.56e+01
#
# Epoch 426: [####################]  100% - Tot. time: 16.5 s
# Loss: 2.54e+01 - Delta: 6.42e-04 - Trend: -1.26e-03
# Val Loss: 2.56e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 18.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.42e-03 | 4.31e-02 |
# | leptoquark | 2.92e-05 | 7.46e-04 | 1.48e-02 |
# | hToTauTau  | 9.53e-05 | 1.12e-03 | 2.97e-02 |
# | hChToTauNu | 1.33e-04 | 1.38e-03 | 4.12e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 427: [####################]  100% - Tot. time: 16.7 s
# Loss: 2.54e+01 - Delta: -1.18e-02 - Trend: -1.24e-02
# Val Loss: 2.56e+01
#
# Epoch 428: [####################]  100% - Tot. time: 16.8 s
# Loss: 2.54e+01 - Delta: -1.60e-03 - Trend: 1.02e-02
# Val Loss: 2.56e+01
#
# Epoch 429: [####################]  100% - Tot. time: 16.6 s
# Loss: 2.54e+01 - Delta: -6.49e-03 - Trend: -4.89e-03
# Val Loss: 2.56e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.5 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.1 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.37e-03 | 4.30e-02 |
# | leptoquark | 2.92e-05 | 7.46e-04 | 1.47e-02 |
# | hToTauTau  | 9.53e-05 | 1.11e-03 | 2.96e-02 |
# | hChToTauNu | 1.33e-04 | 1.38e-03 | 4.11e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 430: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.54e+01 - Delta: -2.97e-03 - Trend: 3.52e-03
# Val Loss: 2.56e+01
#
# Epoch 431: [####################]  100% - Tot. time: 16.3 s
# Loss: 2.54e+01 - Delta: 4.99e-04 - Trend: 3.47e-03
# Val Loss: 2.56e+01
#
# Epoch 432: [####################]  100% - Tot. time: 17.1 s
# Loss: 2.54e+01 - Delta: 2.25e-04 - Trend: -2.74e-04
# Val Loss: 2.56e+01
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 19.3 s
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 3.14e-04 | 3.40e-03 | 4.29e-02 |
# | leptoquark | 2.92e-05 | 7.46e-04 | 1.47e-02 |
# | hToTauTau  | 9.53e-05 | 1.12e-03 | 2.95e-02 |
# | hChToTauNu | 1.33e-04 | 1.38e-03 | 4.10e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 433: [####################]  100% - Tot. time: 16.4 s
# Loss: 2.54e+01 - Delta: -1.01e-02 - Trend: -1.03e-02
# Val Loss: 2.56e+01
#
# Epoch 434: [#######-------------]  37% - ETA:   10 s   Loss: 2.54e+01 (6.67e-02))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
loss_history['train'] = np.array(loss_history['train'])
matplotlib.rcParams.update({'font.size': 16})

f = plt.figure(figsize=(12,8))

train_loss_flat = loss_history['train'].flatten()
x = np.arange(1, train_loss_flat.shape[0]+1) * float(loss_history['train'].shape[0])/train_loss_flat.shape[0]
plt.plot(x, train_loss_flat, '-', alpha=0.2, color='darkorange')

x = np.arange(1, loss_history['train'].shape[0]+1)
plt.plot(x, loss_history['train'][:,-1], 'o--', label='Train', color='darkorange')
plt.plot(x, loss_history['val'], '*', label='Validatation', color='darkmagenta')

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')
# plt.yscale('log')
plt.ylim(0.9*np.min(train_loss_flat), 1.1*np.max(loss_history['train'][1:, -1]))

f.savefig('plots/TrainingHistory_dAE_v'+AEversion+'.png')

f = open('data/TrainingHistory_dAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(loss_history, f)
f.close()

# %%
f, ax_arr = plt.subplots(2,2, figsize=(12,12))
styles = ['-', '--', ':']
x = BSM_eff['ep']
for i, n in enumerate(dataset.BSM_names):  
    ax = ax_arr[int(i/2),i%2]
    
    BSM_eff[n] = np.array(BSM_eff[n])
    
    for j in range(BSM_eff['p_SM'].shape[0]):
#         ax.plot(x, len(x)*[BSM_eff['p_SM'][j]], color='gray', lw=2, linestyle=styles[j])
        ax.plot(x, BSM_eff[n][:,j], 
                color=dataset.process_colors[n], lw=3, linestyle=styles[j], 
                label=dataset.process_labels[n] + ' @ $\epsilon_{{SM}} = {:1.0e}$'.format(BSM_eff['p_SM'][j]))
        
    ax.set_xlim([0, x[-1]+1])
#     ax.set_ylim([1e-6, 5])
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.grid()
    
    ax.legend(loc='best')
    
f.tight_layout()

f = open('data/AnomalyDetectionHistory_dAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(BSM_eff, f)
f.close()

# %% [markdown]
# # Convergence check

# %%
dataset.charge(dataset.SMMix_val)
x = dataset.inputs
model.eval()
if model.onGPU:
    x_prime = model(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
else:
    x_prime = model(torch.from_numpy(x[:10000])).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000])).cpu().detach().numpy()

# %% [markdown]
# ### Latent space

# %%
for i in range(z.shape[1]):
    x_aux = z[:,i]
    f = plt.figure(i)
    r = (np.min(x_aux), np.max(x_aux))
    plt.hist(x_aux, bins=20, range=r, alpha=0.4, density=True)
    plt.xlabel('$z_{{{}}}$'.format(i))
    dnd.append(f)

# %% [markdown]
# ### Output features

# %%
for i in range(x.shape[2]):
    x_aux = x[:,:,i].flatten()
    if i < 3:
        xp_aux = x_prime[:,:,i].flatten()
    elif i==3:
        xp_aux = np.argmax(x_prime[:,:,6:9], axis=2)
        xp_aux = xp_aux.flatten() - 1
    elif i==4:
        xp_aux = np.argmax(x_prime[:,:,9:14], axis=2).flatten()
        
    f = plt.figure(i)
    r = (min(np.min(x_aux), np.min(xp_aux)), max(np.max(x_aux), np.max(xp_aux)))
    if i == 0:
        r = (0,10)
    plt.hist(x_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.hist(xp_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.xlabel('Particles ' + dataset.feature_names[i])
    plt.yscale('log')
    dnd.append(f)

# %% [markdown]
# # Performance evaluation

# %%
dataset.loadValidationSamples('SM')
# Out:
# Loading Wlnu (2000.0k)
# Loading qcd (1141.9k)
# Loading Zll (773.6k)
# Loading ttbar (989.9k)
# SM Mix limiting stat. sample: qcd (1.14M)
# SM validation weights
# [('Wlnu', 0.99999921893491114253), ('qcd', 1.0), ('Zll', 0.29257605781977745954), ('ttbar', 0.010238898454774046649)]

# %%
model.eval()
for n in dataset.valSamples.keys():
    dataset.loss[n] = np.zeros((0))
    
    dataset.charge(dataset.valSamples[n])
    data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
    pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
    for i, (local_x, _) in enumerate(data_iter):
        pb.show(i)
        if model.onGPU:
            local_x = local_x.cuda(model.N_GPU)
            
        x_prime = model(local_x)
        loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
        dataset.loss[n] = np.concatenate((dataset.loss[n], loss))
# Out:
# Ato4l: [#]  100% - Tot. time: 0.0 s
# leptoquark: [######]  100% - Tot. time: 0.7 s
# hToTauTau: [##############]  100% - Tot. time: 3.2 s
# hChToTauNu: [#######]  100% - Tot. time: 1.1 s
# Wlnu: [####################]  100% - Tot. time: 11.9 s
# qcd: [####################]  100% - Tot. time: 6.6 s
# Zll: [################]  100% - Tot. time: 3.9 s
# ttbar: [####################]  100% - Tot. time: 5.3 s

# %%
dic_ROC = createROC_curve(dataset)
pickle.dump(dic_ROC, open('data/dAE_v{}_ROC_dic.pkl'.format(AEversion), 'wb'))
# Out:
# CumSum accuracy: 1.0000000000000266799

# %%
f_ROC, ax_arr = plt.subplots(2,2, figsize=(12,12))
for i, n in enumerate(dataset.BSM_names):
    f = open('../data/HLFref1811-10276_loss/VAE_all-in-one_v71_ROC1_dict_{}.pkl'.format(n), 'br')
    dRef = pickle.load(f, encoding='bytes')
    f.close()
    
    ax = ax_arr[int(i/2),i%2]
    ax.plot(dRef[b'eff_SM'], dRef[b'eff_BSM'], label=dataset.process_labels[n] + ' HLF',
            linestyle='--', lw=3, color=dataset.process_colors[n])
    ax.plot(dic_ROC[n]['eff_SM'], dic_ROC[n]['eff_BSM'], label=dataset.process_labels[n] + ' PF',
            linestyle='-', lw=3, color=dataset.process_colors[n])
    ax.plot([0, 1], [0, 1], color='gray', lw=2, linestyle=':')
    ax.set_xlim([1e-6, 1.0])
    ax.set_ylim([1e-6, 1.05])
    ax.set_xlabel('SM efficiency')
    ax.set_ylabel('BSM efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.grid()
    
    ax.legend(loc='lower right')
    
f_ROC.tight_layout()

# %% [markdown]
# ## Latent dimension clustering

# %%
from sklearn.manifold import TSNE

# %%
dataset.encoded = {}

for n in dataset.BSM_names:    
    dataset.charge(dataset.valSamples[n][:10000])
    x_in = torch.Tensor(dataset.inputs)
    if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
    dataset.encoded[n] = model.encode(x_in).cpu().detach().numpy()
    
dataset.charge(dataset.SMMix_val[:10000])
x_in = torch.Tensor(dataset.inputs)
if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
dataset.encoded['SMMix'] = model.encode(x_in).cpu().detach().numpy()

# %%
idx_max = 1000 #np.min(list(map(lambda x: x.shape[0], dataset.encoded.values())))
z_dset = np.zeros((0, model.Nk))

for n in dataset.encoded.keys():
    z_dset = np.concatenate((z_dset, dataset.encoded[n][:idx_max]))
    
z_embedded = TSNE(n_components=2).fit_transform(z_dset)

# %%
f = plt.figure(figsize=(8,8))

for i, n in enumerate(dataset.encoded.keys()):
#     if not n in ['Ato4l', 'SMMix']: continue
    aux_z = z_embedded[i*idx_max: (i+1)*idx_max]
    plt.plot(aux_z[:,0], aux_z[:,1], 
             'o',
             color=dataset.process_colors[n], 
             mfc='none',
             label=dataset.process_labels[n])
    
plt.xlabel('Embedded 0')
plt.ylabel('Embedded 1')
plt.legend(loc='best')
f.tight_layout()
