# %% [markdown]
# Like dense v4 but with interraction network

# %%
AEversion = '2'

# %%
import numpy as np
import os, sys, pickle, itertools
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import gpustat
try:
    gpustat.print_gpustat()
except:
    pass
# Out:
# imperium-sm.hep.caltech.edu  Wed Jul 10 08:16:52 2019
# [0] GeForce GTX 1080 | 22'C,   0 % |    11 /  8119 MB |
# [1] GeForce GTX 1080 | 24'C,   0 % |    11 /  8119 MB |
# [2] GeForce GTX 1080 | 26'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 38'C,   0 % |  1492 /  8119 MB | ocerri(1481M)
# [6] GeForce GTX 1080 | 55'C,  16 % |  2794 /  8119 MB | ocerri(2783M)
# [7] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
sys.path.append('../lib')
from progressBar import ProgressBar
from utils import EarlyStopping, createROC_curve, ELU_ProbNorm

# %%
dnd = []

# %% [markdown]
# ## Get the dataset

# %%
from dataLoaders import ParticleDataset

# %%
dataset = ParticleDataset(template='../data/20190708_50part_PtOrder_v2/{}.npy', N_part=20, N_features=5)

# %%
dataset.loadTrainSM(N_train_max=1e7)
dataset.charge(dataset.SMMix_train)
# Out:
# Fetching Wlnu
# Fetching qcd
# Fetching Zll
# Fetching ttbar
# QCD is limiting, using it for both val and split
# Expected 3.38M train
# Expected 3.38M val
#
# Loading Wlnu
# Reloading QCD for validation
# Loading Zll
# Loading ttbar
# +--------+----------+-------+-------+
# | Sample | Evts tot | Train |  Val  |
# +--------+----------+-------+-------+
# |  Wlnu  |  4000k   | 2000k | 2000k |
# |  qcd   |  1166k   | 1142k | 1142k |
# |  Zll   |  1000k   |  226k |  226k |
# | ttbar  |  1000k   |  10k  |  10k  |
# +--------+----------+-------+-------+
# Tot training 3.38 M
# Tot val 3.38 M

# %%
dataset.loadValidationSamples('BSM')
# Out:
# Loading Ato4l (47.7k)
# Loading leptoquark (273.6k)
# Loading hToTauTau (681.8k)
# Loading hChToTauNu (338.5k)

# %% [markdown]
# ## Define the model

# %%
class AEGraphNet(nn.Module):
    def __init__(self, N_part, N_features=5, dim_hidden=20, De=7, Do=1, dim_latent=8, verbose = False):
        super(AEGraphNet, self).__init__()
        self.verbose = verbose
        
        self.p = N_features
        self.No = N_part
        self.De = De
        self.Do = Do
        self.Nk = dim_latent
        
        # Define the T/R matrixes
        self.Rr, self.Rs = self.buildEdgesMatrixes() 
        # As soon dim are fixed and connections are the same this is enough
        
        self.encoder_modules = nn.ModuleDict({
            'fr': self.build_dense(dim_in=2*self.p,
                                   dim_out=self.De,
                                   dim_hidden=dim_hidden),
            'fo': self.build_dense(dim_in=self.p + self.De,
                                   dim_out=self.Do,
                                   dim_hidden=dim_hidden),
            'PhiC': self.build_dense(dim_in=self.No*self.Do,
                                     dim_out=self.Nk,
                                     dim_hidden=self.Nk+self.No*self.Do
                                    )
        })
        
        
        self.decoder_modules = nn.ModuleDict({
            'PhiU': self.build_dense(dim_in=self.Nk,
                                     dim_out=self.No*self.Do,
                                     dim_hidden=self.Nk+self.No*self.Do
                                    ),
            'fr': self.build_dense(dim_in=2*self.Do,
                                   dim_out=self.De,
                                   dim_hidden=dim_hidden),
            'fo': self.build_dense(dim_in=self.Do + self.De,
                                   dim_out=self.p + 3,
                                   dim_hidden=dim_hidden),
            'ChargeDec': self.build_Phi(dim_in=2,
                                   dim_out=3),
            'pdgIdDec': self.build_Phi(dim_in=2,
                                   dim_out=5)
        })
        
        
        self.onGPU = False
             
    def buildEdgesMatrixes(self):
        ### Assume fully connected graph
        Ne = self.No * (self.No - 1)
        self.Ne = Ne
        Rr = torch.zeros(self.No, Ne)
        Rs = torch.zeros(self.No, Ne)
        receiver_sender_list = [i for i in itertools.product(range(self.No), range(self.No)) if i[0]!=i[1]]
        for i, (r, s) in enumerate(receiver_sender_list):
            Rr[r, i] = 1
            Rs[s, i] = 1
        return Rr, Rs
          
    def build_dense(self, dim_in, dim_out, dim_hidden):
        net = nn.Sequential(
                            nn.Linear(dim_in, dim_hidden),
                            nn.ReLU(),
                            nn.Linear(dim_hidden, dim_hidden),
                            nn.ReLU(),
                            nn.Linear(dim_hidden, dim_out),
                          )
        return net

    def build_Phi(self, dim_in, dim_out):
        Phi = nn.Sequential(
                              nn.Linear(dim_in, int(0.5*(dim_out + dim_in))),
                              nn.ReLU(),
                              nn.Linear(int(0.5*(dim_out + dim_in)), dim_out)
                            )
        return Phi
         
    def INlayer(self, x, modules):
        local_p = x.shape[2]
        x = torch.transpose(x, 1, 2).contiguous()

        Orr = torch.matmul(x, self.Rr)
        Ors = torch.matmul(x, self.Rs)
        B = torch.cat([Orr, Ors], dim=1)
        
        ### First MLP ###
        E = modules['fr'](B.view(-1, 2 * local_p))
        del B
        
        E = E.view(-1, self.Ne, self.De)
        E = torch.transpose(E, 1, 2).contiguous()
        Ebar = torch.matmul(E, torch.transpose(self.Rr, 0, 1).contiguous())
        del E
        
        C = torch.cat([x, Ebar], 1)
        del Ebar
        
        C = torch.transpose(C, 1, 2).contiguous()
        O = modules['fo'](C.view(-1, local_p + self.De))
        del C
        local_Do = modules['fo'][-1].out_features
        O = torch.relu(O.view(-1, self.No, local_Do))
        return O
        
    def encode(self, x):
        O = self.INlayer(x, self.encoder_modules)
        O = O.view(-1, self.No * self.Do)
        z_raw = self.encoder_modules['PhiC'](O)
        z = F.hardtanh(z_raw, min_val=-5, max_val=5)
        return z
    
    def decode(self, z):
        O = self.decoder_modules['PhiU'](z)
        O = O.view(-1, self.No, self.Do)
        x_raw = self.INlayer(O, self.decoder_modules)
        
        # --- Formatting x ----
        # pt
        pt = 1. + F.elu(x_raw[:,:,0]).view(-1, self.No, 1)
        sig_pt = 1. + 1e-6 + F.elu(x_raw[:,:,1]).view(-1, self.No, 1)
        # eta
        eta = F.hardtanh(x_raw[:,:,2], min_val=-5, max_val=5).view(-1, self.No, 1)
        sig_eta = 1. + 1e-6 + F.elu(x_raw[:,:,3]).view(-1, self.No, 1)
        # phi
        phi = torch.fmod(torch.abs(x_raw[:,:,4]), 6.2831853072).view(-1, self.No, 1) - 3.14159265359
        sig_phi = 1. + 1e-6 + F.elu(x_raw[:,:,5]).view(-1, self.No, 1)
        # charge
#         charge_cat = F.softmax(self.decoder_modules['ChargeDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 3)
        charge_cat = ELU_ProbNorm(self.decoder_modules['ChargeDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 3)
        # pId
#         pId_cat = F.softmax(self.decoder_modules['pdgIdDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 5)
        pId_cat = ELU_ProbNorm(self.decoder_modules['pdgIdDec'](x_raw[:,:,6:].view(-1,2)), dim=1).view(-1, self.No, 5)
        
        x = torch.cat((pt, eta, phi, sig_pt, sig_eta, sig_phi, charge_cat, pId_cat), 2)
        return x
        
    
    def forward(self, x):
        z = self.encode(x)
        x_prime = self.decode(z)
        return x_prime
    
    def initWeights(self):
        def weights_init(M):
            if hasattr(M, 'weight'):
                nn.init.xavier_normal_(M.weight.data)
        
        self.apply(weights_init)
    
    def useGPU(self, N_GPU=1):
        if torch.cuda.is_available():
            print('Current device: {} ({} available)'.format(torch.cuda.current_device(), 
                                                             torch.cuda.device_count()))
            os.environ['CUDA_VISIBLE_DEVICES'] = str(N_GPU)
            torch.cuda.empty_cache()
            self.N_GPU = N_GPU
            torch.cuda.empty_cache()
            self.cuda(N_GPU)
            self.Rr = self.Rr.cuda(N_GPU)
            self.Rs = self.Rs.cuda(N_GPU)
            gpustat.print_gpustat()
            
            self.onGPU = True
        else: 
            print('GPU not available')

# %%
Latent_dimension = int(2*dataset.inputs.shape[1])
Hidden_dimension = 5*dataset.inputs.shape[2]

model = AEGraphNet(
                   N_part=dataset.inputs.shape[1],
                   N_features=dataset.inputs.shape[2],
                   dim_hidden=Hidden_dimension,
                   dim_latent=Latent_dimension,
                   De=10,
                   Do=10
                  )

print(model)
trainablePars = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('\nTrainable parameters:', trainablePars)

# model.initWeights()
# Out:
# AEGraphNet(
#   (encoder_modules): ModuleDict(
#     (PhiC): Sequential(
#       (0): Linear(in_features=200, out_features=240, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=240, out_features=240, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=240, out_features=40, bias=True)
#     )
#     (fo): Sequential(
#       (0): Linear(in_features=15, out_features=25, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=25, out_features=25, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=25, out_features=10, bias=True)
#     )
#     (fr): Sequential(
#       (0): Linear(in_features=10, out_features=25, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=25, out_features=25, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=25, out_features=10, bias=True)
#     )
#   )
#   (decoder_modules): ModuleDict(
#     (ChargeDec): Sequential(
#       (0): Linear(in_features=2, out_features=2, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=2, out_features=3, bias=True)
#     )
#     (PhiU): Sequential(
#       (0): Linear(in_features=40, out_features=240, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=240, out_features=240, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=240, out_features=200, bias=True)
#     )
#     (fo): Sequential(
#       (0): Linear(in_features=20, out_features=25, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=25, out_features=25, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=25, out_features=8, bias=True)
#     )
#     (fr): Sequential(
#       (0): Linear(in_features=20, out_features=25, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=25, out_features=25, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=25, out_features=10, bias=True)
#     )
#     (pdgIdDec): Sequential(
#       (0): Linear(in_features=2, out_features=3, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=3, out_features=5, bias=True)
#     )
#   )
# )
#
# Trainable parameters: 236957

# %%
model.useGPU(1)
# Out:
# Current device: 0 (8 available)
# imperium-sm.hep.caltech.edu  Wed Jul 10 08:17:27 2019
# [0] GeForce GTX 1080 | 22'C,   0 % |    11 /  8119 MB |
# [1] GeForce GTX 1080 | 27'C,   3 % |   468 /  8119 MB | ocerri(457M)
# [2] GeForce GTX 1080 | 26'C,   0 % |    10 /  8119 MB |
# [3] GeForce GTX 1080 | 23'C,   0 % |    11 /  8119 MB |
# [4] GeForce GTX 1080 | 26'C,   0 % |    11 /  8119 MB |
# [5] GeForce GTX 1080 | 41'C,   7 % |  1492 /  8119 MB | ocerri(1481M)
# [6] GeForce GTX 1080 | 55'C,  15 % |  2794 /  8119 MB | ocerri(2783M)
# [7] GeForce GTX 1080 | 27'C,   0 % |    11 /  8119 MB |

# %% [markdown]
# ## Loss

# %%
def criterion(x_in, x_out, reduction='mean'):
    # Gaussian
    out_gauss = torch.pow((x_in[:,:,:3] - x_out[:,:,:3])/ x_out[:,:,3:6], 2) + torch.log(x_out[:,:,3:6])
    out = torch.sum(out_gauss, dim=2)
    
    #Cat cross entropy charge
    aux = torch.log(x_out[:,:,6:9]).view(-1, 3)
    aux = F.nll_loss(aux, 1+x_in[:,:,3].view(-1).long(), reduction='none')
    out += aux.view(-1, x_in.shape[1])
    
    #Cat cross entropy pId
    aux = torch.log(x_out[:,:,9:14]).view(-1, 5)
    out += F.nll_loss(aux, x_in[:,:,4].view(-1).long(), reduction='none').view(-1, x_in.shape[1])
    
    out_per_evt = torch.sum(out, dim=1)
    
    if reduction == 'mean':
        return torch.mean(out_per_evt)
    elif reduction == 'none':
        return out_per_evt
    else:
        raise

# %% [markdown]
# ## Training

# %%
training_params = {'batch_size': 5000,
                   'shuffle': True,
                   'num_workers': 3
                  }

max_epochs = 500

eval_params = {'batch_size': 5000,
               'num_workers': 3
              }

# %%
# torch.autograd.set_detect_anomaly(True);

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 
                              mode='min',
                              factor=0.3,
                              patience=3,
                              verbose=1,
                              threshold=1e-4,
                              cooldown=2,
                              min_lr=1e-7
                             )

# Early stopping
earlyStopping = EarlyStopping(patient=10)

# %%
train_loss = []
BSM_eff = {'ep': []}
for n in dataset.BSM_names:
    BSM_eff[n] = []

loss_history = {'train': [], 'val': []}
optimizer.zero_grad()
try:
    for epoch in range(max_epochs):
        batch_loss = []

        #### ---- Training ---- ####
        model.train()
        dataset.charge(dataset.SMMix_train)
        train_data_iter = torch.utils.data.DataLoader(dataset, **training_params)
        pb = ProgressBar(len(train_data_iter), percentPrecision=5, headLabel='Epoch {}: '.format(epoch))
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)

            x_prime = model(local_x)        
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid training loss!!!')
                raise NameError('LossNAN')
            batch_loss.append(loss.item())

            tail_label = 'Loss: {:2.2e}'.format(loss.item())
            if len(loss_history['train']) > 0:
                tail_label += ' ({:2.2e})'.format(loss.item() - loss_history['train'][-1][-1])
            pb.show(len(batch_loss)-1, tail_label=tail_label)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        model.eval()
        aux_loss = 0
        N_batches = 0
        for local_x, _ in train_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            aux_loss += loss.item()
            N_batches += 1
        batch_loss.append(aux_loss/N_batches)

        printout = 'Loss: {:2.2e}'.format(batch_loss[-1])
        if len(loss_history['train']) > 0:
            printout += ' - Delta: {:2.2e}'.format(batch_loss[-1] - loss_history['train'][-1][-1])
        if len(loss_history['train']) > 1:
            d2L_de2 = batch_loss[-1] - 2*loss_history['train'][-1][-1] + loss_history['train'][-2][-1]
            printout +=' - Trend: {:2.2e}'.format(d2L_de2)
        print(printout)

        loss_history['train'].append(batch_loss)

        #### ---- Validation ---- ####
        dataset.charge(dataset.SMMix_val)
        val_data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
        aux_loss = 0
        N_batches = 0
        for local_x, _ in val_data_iter:
            if model.onGPU:
                local_x = local_x.cuda(model.N_GPU)
            x_prime = model(local_x)
            loss = criterion(local_x, x_prime)
            if np.isnan(loss.item()) or np.isinf(loss.item()):
                print('Invalid validation loss!!!')
                raise NameError('LossNAN')
            aux_loss += loss.item()
            N_batches += 1
        loss_history['val'].append(aux_loss/N_batches)
        printout = 'Val Loss: {:2.2e}'.format(loss_history['val'][-1])
        print(printout)
        if epoch > 0:
            if loss_history['val'][-1] < np.min(loss_history['val']):
                print('[INFO]: Saving best model')
                torch.save(model.state_dict(), 'data/model_state_dict_iAE_v'+AEversion+'_best.pkl')

        print('')
        if not earlyStopping.check(loss_history['val'][-1]):
            break

        scheduler.step(batch_loss[-1])

        #### ---- Anomaly Detection monitor ---- ####
        if epoch%3 == 0:
            print('------------ Anomaly Detection monitor ------------')
            BSM_eff['ep'].append(epoch)
            dataset.loss['SMMix'] = np.zeros((0))

            pb = ProgressBar(len(val_data_iter), percentPrecision=5, headLabel='SM Mix: ')
            for i, (local_x, _) in enumerate(val_data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss['SMMix'] = np.concatenate((dataset.loss['SMMix'], loss))

            p_SM = np.logspace(base=10, start=-5, stop=-3, num=3)
            if not 'p_SM' in BSM_eff.keys():
                BSM_eff['p_SM'] = p_SM
            q_SM = np.quantile(dataset.loss['SMMix'], 1-p_SM)

            table = PrettyTable(['SM Mix'] + list(map(lambda x: '{:1.2e}'.format(x), p_SM)))

            for n in dataset.BSM_names:
                dataset.loss[n] = np.zeros((0))

                dataset.charge(dataset.valSamples[n])
                data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
                pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
                for i, (local_x, _) in enumerate(data_iter):
                    pb.show(i)
                    if model.onGPU:
                        local_x = local_x.cuda(model.N_GPU)

                    x_prime = model(local_x)
                    loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
                    dataset.loss[n] = np.concatenate((dataset.loss[n], loss))

                out = dataset.loss[n] > np.atleast_2d(q_SM).T
                p_BSM = np.float64(np.sum(out, axis=1, dtype=np.float128)/dataset.loss[n].shape[0])
                BSM_eff[n].append(p_BSM)

                table.add_row([n] + list(map(lambda x: '{:1.2e}'.format(x), p_BSM)))
            print(table)                
            print('---------------------------------------------------\n\n')

    model.eval()
    torch.save(model.state_dict(), 'data/model_state_dict_iAE_v'+AEversion+'.pkl');
except NameError:
    if epoch > 0:
        print ('\n\nModel ended up nan. Recovering best model\n')
        model.load_state_dict(torch.load('data/model_state_dict_iAE_v'+AEversion+'_best.pkl'))
    else:
        raise
# Out:
# Epoch 0: [######--------------]  32% - ETA:   43 s   Loss: 1.57e+02Val Loss: 1.51e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.1 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.1 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 6.77e-03 |
# | leptoquark | 3.65e-05 | 4.42e-04 | 8.61e-03 |
# | hToTauTau  | 4.15e-04 | 3.88e-03 | 3.12e-02 |
# | hChToTauNu | 7.06e-04 | 6.52e-03 | 4.44e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 1: [####################]  100% - Tot. time: 64.9 s
# Loss: 1.48e+02 - Delta: -3.73e+00
# Val Loss: 1.47e+02
#
# Epoch 2: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.46e+02 - Delta: -1.24e+00 - Trend: 2.49e+00
# Val Loss: 1.46e+02
#
# Epoch 3: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.46e+02 - Delta: -6.39e-01 - Trend: 6.05e-01
# Val Loss: 1.46e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.8 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.2 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.13e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.76e-03 |
# | hToTauTau  | 4.11e-04 | 3.92e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 4: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.45e+02 - Delta: -4.52e-01 - Trend: 1.87e-01
# Val Loss: 1.45e+02
#
# Epoch 5: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.45e+02 - Delta: -3.45e-01 - Trend: 1.07e-01
# Val Loss: 1.45e+02
#
# Epoch 6: [####################]  100% - Tot. time: 64.9 s
# Loss: 1.45e+02 - Delta: -2.54e-01 - Trend: 9.05e-02
# Val Loss: 1.45e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.1 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.55e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.79e-03 |
# | hToTauTau  | 4.11e-04 | 3.92e-03 | 3.17e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 7: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.45e+02 - Delta: -1.52e-01 - Trend: 1.02e-01
# Val Loss: 1.44e+02
#
# Epoch 8: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -8.33e-02 - Trend: 6.90e-02
# Val Loss: 1.44e+02
#
# Epoch 9: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -5.16e-02 - Trend: 3.16e-02
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 32.4 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.4 s
# hToTauTau: [####################]  100% - Tot. time: 6.4 s
# hChToTauNu: [####################]  100% - Tot. time: 2.7 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.80e-03 |
# | hToTauTau  | 4.11e-04 | 3.94e-03 | 3.17e-02 |
# | hChToTauNu | 7.00e-04 | 6.59e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 10: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -4.32e-02 - Trend: 8.41e-03
# Val Loss: 1.44e+02
#
# Epoch 11: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -3.07e-02 - Trend: 1.25e-02
# Val Loss: 1.44e+02
#
# Epoch 12: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -5.23e-02 - Trend: -2.16e-02
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.5 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.7 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.79e-03 |
# | hToTauTau  | 4.11e-04 | 3.94e-03 | 3.17e-02 |
# | hChToTauNu | 7.00e-04 | 6.58e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 13: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -3.18e-02 - Trend: 2.05e-02
# Val Loss: 1.44e+02
#
# Epoch 14: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -2.93e-02 - Trend: 2.53e-03
# Val Loss: 1.44e+02
#
# Epoch 15: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -3.12e-02 - Trend: -1.96e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.50e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.92e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.56e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 16: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -2.79e-02 - Trend: 3.31e-03
# Val Loss: 1.44e+02
#
# Epoch 17: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -2.72e-02 - Trend: 6.91e-04
# Val Loss: 1.44e+02
#
# Epoch 18: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -2.43e-02 - Trend: 2.93e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.0 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.2 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.29e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.78e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.17e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
# Epoch 19: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -2.36e-02 - Trend: 6.93e-04
# Val Loss: 1.44e+02
#
# Epoch 20: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.87e-02 - Trend: 4.87e-03
# Val Loss: 1.44e+02
#
# Epoch 21: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.01e-02 - Trend: 8.67e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.9 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.9 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.46e-04 | 8.75e-03 |
# | hToTauTau  | 4.11e-04 | 3.91e-03 | 3.16e-02 |
# | hChToTauNu | 7.03e-04 | 6.54e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 22: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.17e-02 - Trend: -1.66e-03
# Val Loss: 1.44e+02
#
# Epoch 23: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -2.37e-02 - Trend: -1.20e-02
# Val Loss: 1.44e+02
#
# Epoch 24: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -1.49e-02 - Trend: 8.83e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 32.5 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.3 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.25e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.78e-03 |
# | hToTauTau  | 4.11e-04 | 3.95e-03 | 3.17e-02 |
# | hChToTauNu | 7.03e-04 | 6.59e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 25: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.30e-02 - Trend: 1.86e-03
# Val Loss: 1.44e+02
#
# Epoch 26: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -9.28e-03 - Trend: 3.74e-03
# Val Loss: 1.44e+02
#
# Epoch 27: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -7.07e-03 - Trend: 2.21e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.8 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.78e-03 |
# | hToTauTau  | 4.11e-04 | 3.94e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 28: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 2.45e-04 - Trend: 7.32e-03
# Val Loss: 1.44e+02
#
# Epoch 29: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.95e-02 - Trend: -1.98e-02
# Val Loss: 1.44e+02
#
# Epoch 30: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.70e-03 - Trend: 1.78e-02
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.4 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.7 s
# hChToTauNu: [####################]  100% - Tot. time: 2.7 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.25e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.78e-03 |
# | hToTauTau  | 4.11e-04 | 3.94e-03 | 3.16e-02 |
# | hChToTauNu | 7.03e-04 | 6.59e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 31: [####################]  100% - Tot. time: 64.9 s
# Loss: 1.44e+02 - Delta: -1.34e-03 - Trend: 3.65e-04
# Val Loss: 1.44e+02
#
# Epoch 32: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -9.18e-03 - Trend: -7.84e-03
# Val Loss: 1.44e+02
#
# Epoch 33: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -4.34e-03 - Trend: 4.84e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.9 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.50e-04 | 8.75e-03 |
# | hToTauTau  | 4.11e-04 | 3.92e-03 | 3.16e-02 |
# | hChToTauNu | 7.03e-04 | 6.56e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 34: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -4.19e-03 - Trend: 1.51e-04
# Val Loss: 1.44e+02
#
# Epoch 35: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -8.66e-03 - Trend: -4.48e-03
# Val Loss: 1.44e+02
#
# Epoch 36: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 7.29e-04 - Trend: 9.39e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [###############-----]  78% - ETA:    1 s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Epoch 91: [####################]  100% - Tot. time: 64.9 s
# Loss: 1.44e+02 - Delta: 1.35e-07 - Trend: -2.91e-04
# Val Loss: 1.44e+02
#
# Epoch 92: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 1.38e-04 - Trend: 1.38e-04
# Val Loss: 1.44e+02
#
# Epoch 93: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.87e-04 - Trend: -3.25e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.7 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.94e-03 | 3.17e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 94: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 2.61e-04 - Trend: 4.48e-04
# Val Loss: 1.44e+02
#
# Epoch 95: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -5.30e-04 - Trend: -7.91e-04
# Val Loss: 1.44e+02
#
# Epoch 96: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 1.36e-04 - Trend: 6.66e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.6 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 97: [####################]  100% - Tot. time: 64.9 s
# Loss: 1.44e+02 - Delta: 2.10e-04 - Trend: 7.46e-05
# Val Loss: 1.44e+02
#
# Epoch 98: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 1.64e-04 - Trend: -4.60e-05
# Val Loss: 1.44e+02
#
# Epoch 99: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 2.78e-05 - Trend: -1.37e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.4 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.7 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 100: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -3.36e-04 - Trend: -3.63e-04
# Val Loss: 1.44e+02
#
# Epoch 101: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 3.43e-04 - Trend: 6.79e-04
# Val Loss: 1.44e+02
#
# Epoch 102: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -8.38e-05 - Trend: -4.27e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.5 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 103: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -1.14e-04 - Trend: -3.03e-05
# Val Loss: 1.44e+02
#
# Epoch 104: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 8.60e-05 - Trend: 2.00e-04
# Val Loss: 1.44e+02
#
# Epoch 105: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -4.51e-04 - Trend: -5.37e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.1 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 6.2 s
# hChToTauNu: [####################]  100% - Tot. time: 3.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 106: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 3.06e-04 - Trend: 7.57e-04
# Val Loss: 1.44e+02
#
# Epoch 107: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -6.93e-05 - Trend: -3.75e-04
# Val Loss: 1.44e+02
#
# Epoch 108: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 1.07e-04 - Trend: 1.76e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.2 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 109: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 6.44e-04 - Trend: 5.37e-04
# Val Loss: 1.44e+02
#
# Epoch 110: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -1.07e-03 - Trend: -1.71e-03
# Val Loss: 1.44e+02
#
# Epoch 111: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 3.36e-04 - Trend: 1.40e-03
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 33.2 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.8 s
# hChToTauNu: [####################]  100% - Tot. time: 3.1 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 112: [####################]  100% - Tot. time: 65.3 s
# Loss: 1.44e+02 - Delta: 1.36e-04 - Trend: -2.00e-04
# Val Loss: 1.44e+02
#
# Epoch 113: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -3.87e-04 - Trend: -5.23e-04
# Val Loss: 1.44e+02
#
# Epoch 114: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 5.85e-05 - Trend: 4.46e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.3 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 6.2 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 115: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 4.39e-04 - Trend: 3.81e-04
# Val Loss: 1.44e+02
#
# Epoch 116: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: -1.54e-04 - Trend: -5.93e-04
# Val Loss: 1.44e+02
#
# Epoch 117: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 1.09e-04 - Trend: 2.63e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 31.0 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.4 s
# hToTauTau: [####################]  100% - Tot. time: 6.4 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 118: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: 2.85e-04 - Trend: 1.76e-04
# Val Loss: 1.44e+02
#
# Epoch 119: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -3.73e-04 - Trend: -6.58e-04
# Val Loss: 1.44e+02
#
# Epoch 120: [####################]  100% - Tot. time: 65.0 s
# Loss: 1.44e+02 - Delta: -8.31e-05 - Trend: 2.90e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 30.8 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.9 s
# hChToTauNu: [####################]  100% - Tot. time: 2.8 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 121: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 2.79e-05 - Trend: 1.11e-04
# Val Loss: 1.44e+02
#
# Epoch 122: [####################]  100% - Tot. time: 65.2 s
# Loss: 1.44e+02 - Delta: -1.35e-04 - Trend: -1.63e-04
# Val Loss: 1.44e+02
#
# Epoch 123: [####################]  100% - Tot. time: 65.2 s
# Loss: 1.44e+02 - Delta: 7.85e-05 - Trend: 2.14e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 29.7 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.3 s
# hToTauTau: [####################]  100% - Tot. time: 5.8 s
# hChToTauNu: [####################]  100% - Tot. time: 2.9 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.49e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 124: [####################]  100% - Tot. time: 65.1 s
# Loss: 1.44e+02 - Delta: 3.14e-04 - Trend: 2.35e-04
# Val Loss: 1.44e+02
#
# Epoch 125: [####################]  100% - Tot. time: 65.7 s
# Loss: 1.44e+02 - Delta: -1.89e-04 - Trend: -5.03e-04
# Val Loss: 1.44e+02
#
# Epoch 126: [####################]  100% - Tot. time: 70.7 s
# Loss: 1.44e+02 - Delta: 2.94e-05 - Trend: 2.19e-04
# Val Loss: 1.44e+02
#
# ------------ Anomaly Detection monitor ------------
# SM Mix: [####################]  100% - Tot. time: 56.6 s
# Ato4l: [##########]  100% - Tot. time: 0.4 s
# leptoquark: [####################]  100% - Tot. time: 2.8 s
# hToTauTau: [####################]  100% - Tot. time: 8.4 s
# hChToTauNu: [####################]  100% - Tot. time: 4.5 s
# +------------+----------+----------+----------+
# |   SM Mix   | 1.00e-05 | 1.00e-04 | 1.00e-03 |
# +------------+----------+----------+----------+
# |   Ato4l    | 4.19e-05 | 5.24e-04 | 7.27e-03 |
# | leptoquark | 3.65e-05 | 4.53e-04 | 8.77e-03 |
# | hToTauTau  | 4.11e-04 | 3.93e-03 | 3.16e-02 |
# | hChToTauNu | 7.00e-04 | 6.57e-03 | 4.50e-02 |
# +------------+----------+----------+----------+
# ---------------------------------------------------
#
#
# Epoch 127: [####################]  100% - Tot. time: 70.2 s
# Loss: 1.44e+02 - Delta: -1.58e-04 - Trend: -1.87e-04
# Val Loss: 1.44e+02
#
# Epoch 128: [####################]  100% - Tot. time: 68.5 s
# Loss: 1.44e+02 - Delta: -1.20e-04 - Trend: 3.76e-05
# Val Loss: 1.44e+02
#
# Epoch 129: [###-----------------]  17% - ETA:   56 s   Loss: 1.44e+02 (-2.22e-01)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
loss_history['train'] = np.array(loss_history['train'])
matplotlib.rcParams.update({'font.size': 16})

f = plt.figure(figsize=(12,8))

train_loss_flat = loss_history['train'].flatten()
x = np.arange(1, train_loss_flat.shape[0]+1) * float(loss_history['train'].shape[0])/train_loss_flat.shape[0]
plt.plot(x, train_loss_flat, '-', alpha=0.2, color='darkorange')

x = np.arange(1, loss_history['train'].shape[0]+1)
plt.plot(x, loss_history['train'][:,-1], 'o--', label='Train', color='darkorange')
plt.plot(x, loss_history['val'], '*', label='Validatation', color='darkmagenta')

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')
# plt.yscale('log')
plt.ylim(0.9*np.min(train_loss_flat), 1.1*np.max(loss_history['train'][1:, -1]))

f.savefig('plots/TrainingHistory_iAE_v'+AEversion+'.png')

f = open('data/TrainingHistory_iAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(loss_history, f)
f.close()

# %%
f, ax_arr = plt.subplots(2,2, figsize=(12,12))
styles = ['-', '--', ':']
x = BSM_eff['ep']
for i, n in enumerate(dataset.BSM_names):  
    ax = ax_arr[int(i/2),i%2]
    
    BSM_eff[n] = np.array(BSM_eff[n])
    
    for j in range(BSM_eff['p_SM'].shape[0]):
#         ax.plot(x, len(x)*[BSM_eff['p_SM'][j]], color='gray', lw=2, linestyle=styles[j])
        ax.plot(x, BSM_eff[n][:,j], 
                color=dataset.process_colors[n], lw=3, linestyle=styles[j], 
                label=dataset.process_labels[n] + ' @ $\epsilon_{{SM}} = {:1.0e}$'.format(BSM_eff['p_SM'][j]))
        
    ax.set_xlim([0, x[-1]+1])
#     ax.set_ylim([1e-6, 5])
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.grid()
    
    ax.legend(loc='best')
    
f.tight_layout()

f = open('data/AnomalyDetectionHistory_iAE_v'+AEversion+'.pkl', 'wb')
pickle.dump(BSM_eff, f)
f.close()

# %% [markdown]
# # Convergence check

# %%
dataset.charge(dataset.SMMix_val)
x = dataset.inputs
model.eval()
if model.onGPU:
    x_prime = model(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000]).cuda(model.N_GPU)).cpu().detach().numpy()
else:
    x_prime = model(torch.from_numpy(x[:10000])).cpu().detach().numpy()
    z = model.encode(torch.from_numpy(x[:10000])).cpu().detach().numpy()

# %% [markdown]
# ### Latent space

# %%
for i in range(z.shape[1]):
    x_aux = z[:,i]
    f = plt.figure(i)
    r = (np.min(x_aux), np.max(x_aux))
    plt.hist(x_aux, bins=20, range=r, alpha=0.4, density=True)
    plt.xlabel('$z_{{{}}}$'.format(i))
    dnd.append(f)
# Out:
# /nfshome/ocerri/miniconda2/envs/PartAN/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Output features

# %%
for i in range(x.shape[2]):
    x_aux = x[:,:,i].flatten()
    if i < 3:
        xp_aux = x_prime[:,:,i].flatten()
    elif i==3:
        xp_aux = np.argmax(x_prime[:,:,6:9], axis=2)
        xp_aux = xp_aux.flatten() - 1
    elif i==4:
        xp_aux = np.argmax(x_prime[:,:,9:14], axis=2).flatten()
        
    f = plt.figure(i)
    r = (min(np.min(x_aux), np.min(xp_aux)), max(np.max(x_aux), np.max(xp_aux)))
    if i == 0:
        r = (0,10)
    plt.hist(x_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.hist(xp_aux, bins=30, range=r, alpha=0.4, density=True)
    plt.xlabel('Particles ' + dataset.feature_names[i])
    plt.yscale('log')
    dnd.append(f)

# %% [markdown]
# # Performance evaluation

# %%
dataset.loadValidationSamples('SM')
# Out:
# Loading Wlnu (2000.0k)
# Loading qcd (1141.9k)
# Loading Zll (773.6k)
# Loading ttbar (989.9k)
# SM Mix limiting stat. sample: qcd (1.14M)
# SM validation weights
# [('Wlnu', 0.99999921893491114253), ('qcd', 1.0), ('Zll', 0.29257605781977745954), ('ttbar', 0.010238898454774046649)]

# %%
model.eval()
for n in dataset.valSamples.keys():
    dataset.loss[n] = np.zeros((0))
    
    dataset.charge(dataset.valSamples[n])
    data_iter = torch.utils.data.DataLoader(dataset, **eval_params)
    pb = ProgressBar(len(data_iter), percentPrecision=5, headLabel=n+': ')
    for i, (local_x, _) in enumerate(data_iter):
        pb.show(i)
        if model.onGPU:
            local_x = local_x.cuda(model.N_GPU)
            
        x_prime = model(local_x)
        loss = criterion(local_x, x_prime, 'none').cpu().detach().numpy()
        dataset.loss[n] = np.concatenate((dataset.loss[n], loss))
# Out:
# Ato4l: [##########]  100% - Tot. time: 0.6 s
# leptoquark: [####################]  100% - Tot. time: 2.9 s
# hToTauTau: [####################]  100% - Tot. time: 8.0 s
# hChToTauNu: [####################]  100% - Tot. time: 3.6 s
# Wlnu: [####################]  100% - Tot. time: 24.6 s
# qcd: [####################]  100% - Tot. time: 14.2 s
# Zll: [####################]  100% - Tot. time: 9.4 s
# ttbar: [####################]  100% - Tot. time: 13.2 s

# %%
dic_ROC = createROC_curve(dataset)
pickle.dump(dic_ROC, open('data/iAE_v{}_ROC_dic.pkl'.format(AEversion), 'wb'))
# Out:
# CumSum accuracy: 1.0000000000000132162

# %%
f_ROC, ax_arr = plt.subplots(2,2, figsize=(12,12))
for i, n in enumerate(dataset.BSM_names):
    f = open('../data/HLFref1811-10276_loss/VAE_all-in-one_v71_ROC1_dict_{}.pkl'.format(n), 'br')
    dRef = pickle.load(f, encoding='bytes')
    f.close()
    
    ax = ax_arr[int(i/2),i%2]
    ax.plot(dRef[b'eff_SM'], dRef[b'eff_BSM'], label=dataset.process_labels[n] + ' HLF',
            linestyle='--', lw=3, color=dataset.process_colors[n])
    ax.plot(dic_ROC[n]['eff_SM'], dic_ROC[n]['eff_BSM'], label=dataset.process_labels[n] + ' PF',
            linestyle='-', lw=3, color=dataset.process_colors[n])
    ax.plot([0, 1], [0, 1], color='gray', lw=2, linestyle=':')
    ax.set_xlim([1e-6, 1.0])
    ax.set_ylim([1e-6, 1.05])
    ax.set_xlabel('SM efficiency')
    ax.set_ylabel('BSM efficiency')
    ax.set_title('')
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.grid()
    
    ax.legend(loc='lower right')
    
f_ROC.tight_layout()

# %% [markdown]
# ## Latent dimension clustering

# %%
from sklearn.manifold import TSNE

# %%
dataset.encoded = {}

for n in dataset.BSM_names:    
    dataset.charge(dataset.valSamples[n][:10000])
    x_in = torch.Tensor(dataset.inputs)
    if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
    dataset.encoded[n] = model.encode(x_in).cpu().detach().numpy()
    
dataset.charge(dataset.SMMix_val[:10000])
x_in = torch.Tensor(dataset.inputs)
if model.onGPU:
        x_in = x_in.cuda(model.N_GPU)
dataset.encoded['SMMix'] = model.encode(x_in).cpu().detach().numpy()

# %%
idx_max = 1000 #np.min(list(map(lambda x: x.shape[0], dataset.encoded.values())))
z_dset = np.zeros((0, model.Nk))

for n in dataset.encoded.keys():
    z_dset = np.concatenate((z_dset, dataset.encoded[n][:idx_max]))
    
z_embedded = TSNE(n_components=2).fit_transform(z_dset)

# %%
f = plt.figure(figsize=(8,8))

for i, n in enumerate(dataset.encoded.keys()):
#     if not n in ['Ato4l', 'SMMix']: continue
    aux_z = z_embedded[i*idx_max: (i+1)*idx_max]
    plt.plot(aux_z[:,0], aux_z[:,1], 
             'o',
             color=dataset.process_colors[n], 
             mfc='none',
             label=dataset.process_labels[n])
    
plt.xlabel('Embedded 0')
plt.ylabel('Embedded 1')
plt.legend(loc='best')
f.tight_layout()
